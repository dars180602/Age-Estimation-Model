# %%
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import cv2
#import os
from zipfile import ZipFile
import time
from datetime import datetime
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras import utils
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.utils import shuffle

# Setting random seeds to reduce the amount of randomness in the neural net weights and results
# The results may still not be exactly reproducible
np.random.seed(42)
tf.random.set_seed(42)

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!unzip "/content/drive/My Drive/Wiki.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: imdb_crop/98/nm2140098_rm221349888_1987-8-30_2005.jpg
#   inflating: imdb_crop/98/nm2140098_rm238127104_1987-8-30_2005.jpg
#   inflating: imdb_crop/98/nm2140098_rm254904320_1987-8-30_2005.jpg
#   inflating: imdb_crop/98/nm2140098_rm3246080_1987-8-30_2005.jpg
#   inflating: imdb_crop/98/nm2140098_rm357599232_1987-8-30_2005.jpg
#   inflating: imdb_crop/98/nm2140098_rm4266559488_1987-8-30_2005.jpg
#   inflating: imdb_crop/98/nm2141398_rm743622144_1981-10-15_2014.jpg
#   inflating: imdb_crop/98/nm2171898_rm1728443392_1982-1-16_2011.jpg
#   inflating: imdb_crop/98/nm2171898_rm1903294208_1982-1-16_2015.jpg
#   inflating: imdb_crop/98/nm2171898_rm4126077440_1982-1-16_2015.jpg
#   inflating: imdb_crop/98/nm2171898_rm4149856000_1982-1-16_2014.jpg
#   inflating: imdb_crop/98/nm2197298_rm1011720704_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm1028497920_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm1105825024_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm1139378944_1988-9-19_2009.jpg
#   inflating: imdb_crop/98/nm2197298_rm1206488320_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm1655539200_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm1668994560_1988-9-19_2013.jpg
#   inflating: imdb_crop/98/nm2197298_rm1685771776_1988-9-19_2013.jpg
#   inflating: imdb_crop/98/nm2197298_rm1840090624_1988-9-19_2009.jpg
#   inflating: imdb_crop/98/nm2197298_rm1856867840_1988-9-19_2009.jpg
#   inflating: imdb_crop/98/nm2197298_rm1923974656_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm1940751872_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm1957529088_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm2351600640_1988-9-19_2008.jpg
#   inflating: imdb_crop/98/nm2197298_rm2557324800_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm2680855296_1988-9-19_2008.jpg
#   inflating: imdb_crop/98/nm2197298_rm2820309760_1988-9-19_2013.jpg
#   inflating: imdb_crop/98/nm2197298_rm3008790784_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm3451568640_1988-9-19_2013.jpg
#   inflating: imdb_crop/98/nm2197298_rm3585266688_1988-9-19_2013.jpg
#   inflating: imdb_crop/98/nm2197298_rm3661532928_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm3662455296_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm3678310144_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm3695087360_1988-9-19_2010.jpg
#   inflating: imdb_crop/98/nm2197298_rm3782061568_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm3949833728_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm462073600_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm531336704_1988-9-19_2013.jpg
#   inflating: imdb_crop/98/nm2197298_rm661963264_1988-9-19_2014.jpg
#   inflating: imdb_crop/98/nm2197298_rm668645120_1988-9-19_2012.jpg
#   inflating: imdb_crop/98/nm2197298_rm69187328_1988-9-19_2012.jpg
#   inflating: imdb_crop/98/nm2197298_rm717597952_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm872134400_1988-9-19_2012.jpg
#   inflating: imdb_crop/98/nm2197298_rm877502976_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm902147328_1988-9-19_2006.jpg
#   inflating: imdb_crop/98/nm2197298_rm945526272_1988-9-19_2008.jpg
#   inflating: imdb_crop/98/nm2197298_rm964135168_1988-9-19_2009.jpg
#   inflating: imdb_crop/98/nm2197298_rm980912384_1988-9-19_2009.jpg
#   inflating: imdb_crop/98/nm2255698_rm2825777152_1989-3-3_2011.jpg
#   inflating: imdb_crop/98/nm2255698_rm716437760_1989-3-3_2012.jpg
#   inflating: imdb_crop/98/nm2255698_rm884209920_1989-3-3_2012.jpg
#   inflating: imdb_crop/98/nm2255698_rm900987136_1989-3-3_2014.jpg
#   inflating: imdb_crop/98/nm2275298_rm1028765184_1979-6-17_2011.jpg
#   inflating: imdb_crop/98/nm2444298_rm1116265216_1982-11-4_2013.jpg
#   inflating: imdb_crop/98/nm2444298_rm1133042432_1982-11-4_2013.jpg
#   inflating: imdb_crop/98/nm2444298_rm1200151296_1982-11-4_2013.jpg
#   inflating: imdb_crop/98/nm2444298_rm2022234880_1982-11-4_2013.jpg
#   inflating: imdb_crop/98/nm2444298_rm4125356032_1982-11-4_2014.jpg
#   inflating: imdb_crop/98/nm2471798_rm1029017344_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm103331328_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm106213888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm106270464_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm107722496_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1084195328_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1102816768_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1124006144_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm112429824_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1196393472_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1213184256_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1220257280_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1223292928_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm123047680_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1237034496_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1239923200_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm124499712_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1256700416_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1263515904_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1273477632_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1275001088_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1280293120_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1290254848_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1291778304_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1307032064_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1313847552_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1320920576_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1323809280_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1335853568_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1337697792_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1347323648_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1347597056_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1362078976_1981-4-30_2013.jpg
#   inflating: imdb_crop/98/nm2471798_rm1364100864_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1379118592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1412410624_1981-4-30_2013.jpg
#   inflating: imdb_crop/98/nm2471798_rm1464842496_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1466226432_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1486868480_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1531873024_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1548650240_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1548923648_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1565427456_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1582204672_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1598981888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1602070016_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1614336_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1632087040_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1645645312_1981-4-30_2010.jpg
#   inflating: imdb_crop/98/nm2471798_rm1648864256_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1682418688_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1686224128_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm169386496_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1701107456_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1717884672_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1722725888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1734661888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1815063808_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm181925632_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm186163712_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1892125952_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm19126528_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1925680384_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm1956359424_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2011469056_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2018477056_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2149698304_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2150743296_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2156513792_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2173291008_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2182727936_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2184297728_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2203551232_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2215227136_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2220328448_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2223473664_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2232004352_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2240399872_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2247012608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2249836800_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2251406592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2265229312_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2268183808_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2281803520_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2283391232_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2283916032_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2300168448_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2301986560_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2318763776_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2326310400_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2333722880_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2335540992_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2349312_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2350500096_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2351024896_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2357104128_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2359864832_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2367277312_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm237549056_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm23836416_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2400831744_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2404877824_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2408172032_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2419689728_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2436466944_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2441719552_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2441851904_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2470021376_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2473713408_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2483130112_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2486798592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2492183552_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2499907328_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2507267840_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2533461760_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2535049472_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2558063360_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2576713984_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm258717440_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2592846848_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2609624064_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2610268416_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2620442624_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2626268928_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2627045632_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2654570752_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2670774272_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2671347968_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2694828032_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm270839040_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2721814528_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2728382464_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2738073088_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2745926144_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2759697920_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2762703360_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2769718784_1981-4-30_2010.jpg
#   inflating: imdb_crop/98/nm2471798_rm2772339968_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2779480576_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2780542976_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2788923392_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm279097856_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2795491328_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2796257792_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2797320192_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2805894400_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2810029568_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2822477824_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2825572608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2826806784_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2833022976_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2860425984_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2864811776_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2875904256_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm287616256_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2881588992_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2883354624_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2893915648_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2893980416_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2904019200_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2910757632_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2943013120_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2944312064_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2964884992_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2981662208_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm299366144_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2997205760_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm2998439424_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3007027200_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3013982976_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3015216640_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3016609792_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3023804416_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm304393472_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3061752576_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3065548288_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3066941440_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3074136064_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3083718656_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3085545472_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3094470400_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3104090112_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3104419584_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3119427840_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3120867328_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3123821824_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm312652288_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3131423488_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3136205056_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3137644544_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3145573888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3154421760_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3163139840_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3181755136_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3194925568_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3195905536_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3198532352_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3212682752_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3243542784_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3260320000_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3277097216_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3291131904_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3293874432_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm329429504_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3294410496_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3297431040_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3303116544_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3310651648_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3319893760_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3324686336_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3329866240_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3336670976_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3353448192_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3360354816_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3412956160_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3428092160_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3442526208_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3444240896_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3444869376_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3461646592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3472384_1981-4-30_2015.jpg
#   inflating: imdb_crop/98/nm2471798_rm3524364544_1981-4-30_2009.jpg
#   inflating: imdb_crop/98/nm2471798_rm3533943040_1981-4-30_2012.jpg
#   inflating: imdb_crop/98/nm2471798_rm3539109888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3541144576_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3565192960_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3572664320_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3612013056_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3615524608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm36222464_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3632177152_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3632839680_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3637619456_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3649616896_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3662804736_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3666185728_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3666394112_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3668160768_1981-4-30_2012.jpg
#   inflating: imdb_crop/98/nm2471798_rm3671173888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3672619008_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3674659840_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3679581952_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3683171328_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3687951104_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3696359168_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3704728320_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3706173440_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3716725760_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3721505536_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3735269632_1981-4-30_2012.jpg
#   inflating: imdb_crop/98/nm2471798_rm3741768704_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3752046848_1981-4-30_2012.jpg
#   inflating: imdb_crop/98/nm2471798_rm3772627200_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3777549568_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3810505216_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm383289088_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3844059648_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3849908992_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3898734592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3902513664_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3911767296_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3928544512_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3950806272_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3954544384_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm3978876160_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4036731392_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm404785920_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4049711360_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4067789568_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm407350272_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4083283968_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4095445248_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4116838400_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4143416832_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4150392832_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4154171904_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4186623488_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4188580608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4192308992_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4202281472_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4209086208_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4218262528_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4218784512_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4219380480_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4225863424_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4235561728_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4236955136_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4240017920_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm424127488_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4250711808_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4253732352_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4256795136_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm4277634560_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm430880256_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm440904704_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm455388416_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm463647232_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm464434688_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm488672000_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm488942848_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm493454848_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm494318592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm505720064_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm510232064_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm522497280_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm531005696_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm539096576_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm554163200_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm558333952_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm562466304_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm579243520_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm609416960_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm636982528_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm638049280_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm646560768_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm651340544_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm653759744_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm659748608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm663337984_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm670536960_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm671603712_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm688380928_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm70233344_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm706868736_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm724879872_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm72659456_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm738712576_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm772267008_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm78875392_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm789044224_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm839813888_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm857863680_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm86554112_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm873368320_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm874640896_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm890145536_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm90945280_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm924972544_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm94478592_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm945074688_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm946583296_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm950116608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm95652608_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm963360512_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm980137728_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2471798_rm983671040_1981-4-30_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm2623379456_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm3758658560_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm3775435776_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm3792212992_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm3808990208_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm3825767424_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2538498_rm4010316800_1979-3-17_2007.jpg
#   inflating: imdb_crop/98/nm2771798_rm1096199424_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1112976640_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1219026176_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1235803392_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1284350464_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1317904896_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1401790976_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1435345408_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1470684416_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm1626448384_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm2164171520_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm2197725952_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm2210037760_1985-0-0_2010.jpg
#   inflating: imdb_crop/98/nm2771798_rm28028672_1985-0-0_2011.jpg
#   inflating: imdb_crop/98/nm2771798_rm2847571968_1985-0-0_2010.jpg
#   inflating: imdb_crop/98/nm2771798_rm290893056_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3082452992_1985-0-0_2010.jpg
#   inflating: imdb_crop/98/nm2771798_rm311350016_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3199893504_1985-0-0_2010.jpg
#   inflating: imdb_crop/98/nm2771798_rm3216670720_1985-0-0_2010.jpg
#   inflating: imdb_crop/98/nm2771798_rm328127232_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3903496960_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3920274176_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3937051392_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3953828608_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm3970605824_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm4023693056_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm441888000_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm529453824_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm594989312_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm678875392_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm729207040_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm779538688_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm880201984_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm896979200_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2771798_rm913756416_1985-0-0_2013.jpg
#   inflating: imdb_crop/98/nm2793398_rm1222684928_1979-9-17_2012.jpg
#   inflating: imdb_crop/98/nm2793398_rm1289793792_1979-9-17_2012.jpg
#   inflating: imdb_crop/98/nm2849998_rm10468096_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm130328320_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm1324141824_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm1441660416_1989-9-25_2008.jpg
#   inflating: imdb_crop/98/nm2849998_rm144685824_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1688189696_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1704966912_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1721744128_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1755298560_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1788852992_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1855961856_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1889516288_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1939847936_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm195017472_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1956625152_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm1973402368_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2006956800_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm211794688_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2282981120_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2299758336_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2316535552_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2350089984_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2366867200_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2383644416_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2434790656_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm245349120_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2519441664_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm278903552_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm2817392128_1989-9-25_2008.jpg
#   inflating: imdb_crop/98/nm2849998_rm3004811776_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3101794560_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm312457984_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm3240752384_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3276918528_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3358192896_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3385576960_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3391747328_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3419131392_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3458856192_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm3679104256_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm379566848_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm3927148288_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm3943925504_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm396344064_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm3977479936_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm3994257152_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm4145252096_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm451333120_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm480230144_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm530561792_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2849998_rm786090752_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm807990528_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm819645184_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm875099392_1989-9-25_2013.jpg
#   inflating: imdb_crop/98/nm2849998_rm949992192_1989-9-25_2010.jpg
#   inflating: imdb_crop/98/nm2876098_rm1056482304_1998-7-7_2013.jpg
#   inflating: imdb_crop/98/nm2876098_rm116958208_1998-7-7_2013.jpg
#   inflating: imdb_crop/98/nm2876098_rm1315619584_1998-7-7_2011.jpg
#   inflating: imdb_crop/98/nm2876098_rm1509537280_1998-7-7_2012.jpg
#   inflating: imdb_crop/98/nm2876098_rm1643236608_1998-7-7_2011.jpg
#   inflating: imdb_crop/98/nm2876098_rm267953152_1998-7-7_2013.jpg
#   inflating: imdb_crop/98/nm2876098_rm2735797504_1998-7-7_2015.jpg
#   inflating: imdb_crop/98/nm2876098_rm2903569664_1998-7-7_2015.jpg
#   inflating: imdb_crop/98/nm2876098_rm3542086912_1998-7-7_2015.jpg
#   inflating: imdb_crop/98/nm2876098_rm3849888768_1998-7-7_2013.jpg
#   inflating: imdb_crop/98/nm2876098_rm402170880_1998-7-7_2013.jpg
#   inflating: imdb_crop/98/nm2876098_rm691513088_1998-7-7_2013.jpg
#   inflating: imdb_crop/98/nm3033898_rm1005229056_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3033898_rm1022006272_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3033898_rm4125660160_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3033898_rm837456896_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3033898_rm904565760_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3033898_rm971674624_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3033898_rm988451840_1989-3-13_2005.jpg
#   inflating: imdb_crop/98/nm3091498_rm1102618624_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm1220059136_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm1237156096_1980-9-1_2008.jpg
#   inflating: imdb_crop/98/nm3091498_rm1253613568_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm1463989248_1980-9-1_2010.jpg
#   inflating: imdb_crop/98/nm3091498_rm1842388992_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm2316215808_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm2390140416_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm2400101888_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm2475412224_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm2643184384_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm299159808_1980-9-1_2014.jpg
#   inflating: imdb_crop/98/nm3091498_rm315937024_1980-9-1_2014.jpg
#   inflating: imdb_crop/98/nm3091498_rm349491456_1980-9-1_2014.jpg
#   inflating: imdb_crop/98/nm3091498_rm366268672_1980-9-1_2014.jpg
#   inflating: imdb_crop/98/nm3091498_rm3789015040_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm3827936768_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm383045888_1980-9-1_2014.jpg
#   inflating: imdb_crop/98/nm3091498_rm4013340928_1980-9-1_2008.jpg
#   inflating: imdb_crop/98/nm3091498_rm4023896064_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3091498_rm575384832_1980-9-1_2013.jpg
#   inflating: imdb_crop/98/nm3140698_rm2164110592_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm2180887808_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm2197665024_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm2415768832_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm2562635008_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm3804148992_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm3837703424_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm3888035072_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3140698_rm3955143936_1988-12-17_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm1123336704_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1140113920_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1173668352_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1173733888_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1207288320_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1274983424_1990-2-19_2011.jpg
#   inflating: imdb_crop/98/nm3297698_rm1327156480_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1358217728_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm1374994944_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm162441216_1990-2-19_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm2717237760_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm2868167168_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm3069493760_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm363767808_1990-2-19_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm3638665984_1990-2-19_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm3655443200_1990-2-19_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm3688997632_1990-2-19_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm454741248_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm612881408_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm629658624_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm646435840_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3297698_rm652387072_1990-2-19_2012.jpg
#   inflating: imdb_crop/98/nm3297698_rm787857920_1990-2-19_2014.jpg
#   inflating: imdb_crop/98/nm3374198_rm2818038528_1987-4-12_2013.jpg
#   inflating: imdb_crop/98/nm3374198_rm3200305408_1987-4-12_2015.jpg
#   inflating: imdb_crop/98/nm3437398_rm135903232_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm152680448_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm270120960_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm286898176_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm320452608_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm354007040_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm370784256_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3437398_rm505001984_1951-6-5_2007.jpg
#   inflating: imdb_crop/98/nm3568698_rm1612687360_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm1750903296_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm17744896_1986-12-11_2013.jpg
#   inflating: imdb_crop/98/nm3568698_rm17869312_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm1814013952_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm1935452672_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm2036115968_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm2589183488_1986-12-11_2014.jpg
#   inflating: imdb_crop/98/nm3568698_rm2605960704_1986-12-11_2014.jpg
#   inflating: imdb_crop/98/nm3568698_rm3230969344_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm3449073152_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm3835540992_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3568698_rm4170493440_1986-12-11_2012.jpg
#   inflating: imdb_crop/98/nm3578998_rm3265823744_1972-11-20_2010.jpg
#   inflating: imdb_crop/98/nm3578998_rm59091968_1972-11-20_2006.jpg
#   inflating: imdb_crop/98/nm3610998_rm1418830592_2000-3-25_2013.jpg
#   inflating: imdb_crop/98/nm3641098_rm1237251072_1991-3-16_2015.jpg
#   inflating: imdb_crop/98/nm3719798_rm3358388736_1984-6-5_2015.jpg
#   inflating: imdb_crop/98/nm3719798_rm3509383680_1984-6-5_2015.jpg
#   inflating: imdb_crop/98/nm3719798_rm3526160896_1984-6-5_2015.jpg
#   inflating: imdb_crop/98/nm3719798_rm3542938112_1984-6-5_2015.jpg
#   inflating: imdb_crop/98/nm3719798_rm3559715328_1984-6-5_2015.jpg
#   inflating: imdb_crop/98/nm3794498_rm1421115904_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm1571392768_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm1572110848_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm1588888064_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm1683787520_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm18713856_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2076019712_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2093976576_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2109574144_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm233540864_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2428011008_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2444788224_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2461565440_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2478342656_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2495119872_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2528674304_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm26512640_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm2772143872_1983-1-1_2010.jpg
#   inflating: imdb_crop/98/nm3794498_rm302222592_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3155201792_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm317817344_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3221916928_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3238694144_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3511847936_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3567488256_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3574828800_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3746728960_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm384926208_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm3859451136_1983-1-1_2010.jpg
#   inflating: imdb_crop/98/nm3794498_rm43289856_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm73564672_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm82545920_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm827886848_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm3794498_rm90341888_1983-1-1_2002.jpg
#   inflating: imdb_crop/98/nm4058898_rm1086636032_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm2033183232_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm203614720_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm2222592_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm2345855488_1986-7-21_2015.jpg
#   inflating: imdb_crop/98/nm4058898_rm2804017664_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3201493504_1986-7-21_2015.jpg
#   inflating: imdb_crop/98/nm4058898_rm321055232_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3307334144_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3334717440_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3367027456_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3468935168_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3703816192_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm3726764544_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4058898_rm4029671936_1986-7-21_2013.jpg
#   inflating: imdb_crop/98/nm4154798_rm1272772352_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1356658432_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1423944192_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm1445383680_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1491053056_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm1491660800_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1524607488_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm1558161920_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm1591716352_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm1709886720_1989-8-10_2013.jpg
#   inflating: imdb_crop/98/nm4154798_rm1793900800_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1827455232_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1957153536_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1973930752_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm1995227392_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm2095890688_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm2209860352_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm224969472_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm2329330176_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm241746688_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm2699012608_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm2732567040_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm2749344256_1989-8-10_2012.jpg
#   inflating: imdb_crop/98/nm4154798_rm301857024_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3310538496_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3344092928_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3444756224_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3461533440_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3478310656_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3630746880_1989-8-10_2014.jpg
#   inflating: imdb_crop/98/nm4154798_rm3647524096_1989-8-10_2014.jpg
# ...
#   inflating: imdb_crop/99/nm1878999_rm1904200960_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm1937755392_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm1988087040_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm2004864256_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm2071973120_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm2076742656_1978-10-31_2008.jpg
#   inflating: imdb_crop/99/nm1878999_rm2088750336_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm2139081984_1978-10-31_2013.jpg
#   inflating: imdb_crop/99/nm1878999_rm2155608320_1978-10-31_2011.jpg
#   inflating: imdb_crop/99/nm1878999_rm2229257472_1978-10-31_2011.jpg
#   inflating: imdb_crop/99/nm1878999_rm2346697984_1978-10-31_2011.jpg
#   inflating: imdb_crop/99/nm1878999_rm2464138496_1978-10-31_2011.jpg
#   inflating: imdb_crop/99/nm1878999_rm3101672704_1978-10-31_2011.jpg
#   inflating: imdb_crop/99/nm1878999_rm3168781568_1978-10-31_2011.jpg
#   inflating: imdb_crop/99/nm1892299_rm2223939840_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm2240717056_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm2315243008_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm2365574656_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm236899840_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm2390599168_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm2550124032_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm3725117952_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm3868434432_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm3901988864_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm3935030016_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm3951807232_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1892299_rm4002138880_1984-9-24_2013.jpg
#   inflating: imdb_crop/99/nm1995299_rm2858335744_1972-4-6_2011.jpg
#   inflating: imdb_crop/99/nm1995299_rm2891890176_1972-4-6_2011.jpg
#   inflating: imdb_crop/99/nm1995299_rm2908667392_1972-4-6_2011.jpg
#   inflating: imdb_crop/99/nm1995299_rm2925444608_1972-4-6_2011.jpg
#   inflating: imdb_crop/99/nm2088699_rm1010759168_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm1014692864_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm1767502592_1978-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2088699_rm2249388288_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2287324672_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2445735680_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2450455552_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm245366272_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2484009984_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm25491968_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2596730624_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2763769088_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2780546304_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2824860160_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm2841637376_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm3076518400_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm3155357952_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm3259351552_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm3328768_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm3336237568_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm3477455360_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm39046656_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm4158817536_1978-0-0_2011.jpg
#   inflating: imdb_crop/99/nm2088699_rm573308416_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm590085632_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm813366272_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm943650304_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm964361216_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2088699_rm981138432_1978-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2124399_rm2111896832_1978-3-16_2013.jpg
#   inflating: imdb_crop/99/nm2156099_rm2937624576_1962-3-27_2004.jpg
#   inflating: imdb_crop/99/nm2156099_rm4103772416_1962-3-27_2006.jpg
#   inflating: imdb_crop/99/nm2156099_rm4154104064_1962-3-27_2006.jpg
#   inflating: imdb_crop/99/nm2156099_rm4288321792_1962-3-27_2006.jpg
#   inflating: imdb_crop/99/nm2164099_rm3506421248_1979-10-18_2012.jpg
#   inflating: imdb_crop/99/nm2164099_rm586202624_1979-10-18_2012.jpg
#   inflating: imdb_crop/99/nm2166399_rm1476710400_1986-11-27_2013.jpg
#   inflating: imdb_crop/99/nm2166399_rm3053768704_1986-11-27_2013.jpg
#   inflating: imdb_crop/99/nm2166399_rm3083456512_1986-11-27_2013.jpg
#   inflating: imdb_crop/99/nm2166399_rm3938045952_1986-11-27_2013.jpg
#   inflating: imdb_crop/99/nm2166399_rm498847744_1986-11-27_2013.jpg
#   inflating: imdb_crop/99/nm2242399_rm1005646080_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1030615296_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1047392512_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm116453632_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm133230848_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1481491712_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1498268928_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1515046144_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1531823360_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1548600576_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1565377792_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm15790336_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm1582155008_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm2773337344_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm2790114560_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm2806891776_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm32567552_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm3643264512_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm560853248_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm577630464_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm594407680_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm611184896_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm728625408_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm778957056_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm795734272_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm812511488_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm82899200_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm846065920_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2242399_rm997060864_1979-1-6_2014.jpg
#   inflating: imdb_crop/99/nm2260999_rm1388615680_1994-11-3_2006.jpg
#   inflating: imdb_crop/99/nm2260999_rm3668941568_1994-11-3_2006.jpg
#   inflating: imdb_crop/99/nm2264199_rm181377792_1995-9-13_2007.jpg
#   inflating: imdb_crop/99/nm2264199_rm3370835200_1995-9-13_2011.jpg
#   inflating: imdb_crop/99/nm2264199_rm3555384576_1995-9-13_2011.jpg
#   inflating: imdb_crop/99/nm2264199_rm3723156736_1995-9-13_2011.jpg
#   inflating: imdb_crop/99/nm2273799_rm2471275776_1982-9-30_2013.jpg
#   inflating: imdb_crop/99/nm2273799_rm3258625280_1982-9-30_2013.jpg
#   inflating: imdb_crop/99/nm2273799_rm3426397440_1982-9-30_2013.jpg
#   inflating: imdb_crop/99/nm2273799_rm3459951872_1982-9-30_2013.jpg
#   inflating: imdb_crop/99/nm2338599_rm684425728_1981-7-18_2011.jpg
#   inflating: imdb_crop/99/nm2354099_rm1423745536_1977-0-0_2013.jpg
#   inflating: imdb_crop/99/nm2436499_rm2081211904_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm2097989120_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm2212154112_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm2262485760_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm2396703488_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm3118123776_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm3134900992_1993-2-14_2014.jpg
#   inflating: imdb_crop/99/nm2436499_rm748781568_1993-2-14_2010.jpg
#   inflating: imdb_crop/99/nm2436499_rm765558784_1993-2-14_2010.jpg
#   inflating: imdb_crop/99/nm2441699_rm1292761088_1981-0-0_2014.jpg
#   inflating: imdb_crop/99/nm2441699_rm2684482048_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2441699_rm2701849088_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2441699_rm2953835008_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2441699_rm3088052736_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2441699_rm3104829952_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2441699_rm4194431488_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2441699_rm4262130176_1981-0-0_2015.jpg
#   inflating: imdb_crop/99/nm2648599_rm382240256_1979-9-26_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm1121054720_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm1139538944_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm153867520_1966-8-11_2014.jpg
#   inflating: imdb_crop/99/nm2788999_rm1638574848_1966-8-11_2012.jpg
#   inflating: imdb_crop/99/nm2788999_rm1774841856_1966-8-11_2013.jpg
#   inflating: imdb_crop/99/nm2788999_rm2028731392_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm217644032_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm2292024320_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm2308877056_1966-8-11_2012.jpg
#   inflating: imdb_crop/99/nm2788999_rm2354115328_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm2543682560_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm2564139520_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm2731923968_1966-8-11_2011.jpg
#   inflating: imdb_crop/99/nm2788999_rm2747239424_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm2761786368_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm2850408192_1966-8-11_2011.jpg
#   inflating: imdb_crop/99/nm2788999_rm2916473344_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm2967643904_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm3050691072_1966-8-11_2011.jpg
#   inflating: imdb_crop/99/nm2788999_rm3231548416_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm338416896_1966-8-11_2014.jpg
#   inflating: imdb_crop/99/nm2788999_rm3623335424_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm3627254784_1966-8-11_2011.jpg
#   inflating: imdb_crop/99/nm2788999_rm3677586432_1966-8-11_2011.jpg
#   inflating: imdb_crop/99/nm2788999_rm3745299456_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm3843139328_1966-8-11_2014.jpg
#   inflating: imdb_crop/99/nm2788999_rm3846028288_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm3884698624_1966-8-11_2014.jpg
#   inflating: imdb_crop/99/nm2788999_rm402193408_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm439854848_1966-8-11_2014.jpg
#   inflating: imdb_crop/99/nm2788999_rm455857408_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm624802816_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm725466112_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm826129408_1966-8-11_2010.jpg
#   inflating: imdb_crop/99/nm2788999_rm83426304_1966-8-11_2015.jpg
#   inflating: imdb_crop/99/nm2788999_rm840480768_1966-8-11_2011.jpg
#   inflating: imdb_crop/99/nm2957199_rm1408076544_1990-0-0_2004.jpg
#   inflating: imdb_crop/99/nm2957199_rm1491962624_1990-0-0_2004.jpg
#   inflating: imdb_crop/99/nm2957199_rm1559071488_1990-0-0_2004.jpg
#   inflating: imdb_crop/99/nm2957199_rm394308864_1990-0-0_2012.jpg
#   inflating: imdb_crop/99/nm3037999_rm3063926528_1988-0-0_2013.jpg
#   inflating: imdb_crop/99/nm3135499_rm3904287232_2004-1-10_2011.jpg
#   inflating: imdb_crop/99/nm3135499_rm4172722688_2004-1-10_2011.jpg
#   inflating: imdb_crop/99/nm3135499_rm4239831552_2004-1-10_2011.jpg
#   inflating: imdb_crop/99/nm3277599_rm1066662912_1986-0-0_2015.jpg
#   inflating: imdb_crop/99/nm3277599_rm3969121280_1986-0-0_2015.jpg
#   inflating: imdb_crop/99/nm3289599_rm1021898752_1981-3-12_2015.jpg
#   inflating: imdb_crop/99/nm3289599_rm1469175808_1981-3-12_2013.jpg
#   inflating: imdb_crop/99/nm3289599_rm4248614400_1981-3-12_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm104508928_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1284410368_1990-3-26_2010.jpg
#   inflating: imdb_crop/99/nm3361199_rm1301187584_1990-3-26_2010.jpg
#   inflating: imdb_crop/99/nm3361199_rm1363327232_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1514322176_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1531099392_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1547876608_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1581431040_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1598208256_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1632218880_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1682550528_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1717760000_1990-3-26_2015.jpg
#   inflating: imdb_crop/99/nm3361199_rm1734537216_1990-3-26_2015.jpg
#   inflating: imdb_crop/99/nm3361199_rm1762566400_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1951904000_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm1963892992_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm2558824192_1990-3-26_2010.jpg
#   inflating: imdb_crop/99/nm3361199_rm2575601408_1990-3-26_2010.jpg
#   inflating: imdb_crop/99/nm3361199_rm2760805376_1990-3-26_2010.jpg
#   inflating: imdb_crop/99/nm3361199_rm2806167808_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm2851454208_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm2982982656_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm2999759872_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm3477535744_1990-3-26_2013.jpg
#   inflating: imdb_crop/99/nm3361199_rm3625645312_1990-3-26_2015.jpg
#   inflating: imdb_crop/99/nm3361199_rm3760562176_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm3800338176_1990-3-26_2010.jpg
#   inflating: imdb_crop/99/nm3361199_rm4196769792_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm4280655872_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm457813760_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm474590976_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm54177280_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm549301504_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm566078720_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm582855936_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm605811968_1990-3-26_2015.jpg
#   inflating: imdb_crop/99/nm3361199_rm708488704_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm725265920_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm767405312_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm775597568_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm825929216_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm842706432_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm876260864_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm87731712_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3361199_rm993701376_1990-3-26_2011.jpg
#   inflating: imdb_crop/99/nm3724099_rm129678592_1997-7-5_2010.jpg
#   inflating: imdb_crop/99/nm3724099_rm2764539648_1997-7-5_2010.jpg
#   inflating: imdb_crop/99/nm3724099_rm2814871296_1997-7-5_2010.jpg
#   inflating: imdb_crop/99/nm3724099_rm2915534592_1997-7-5_2010.jpg
#   inflating: imdb_crop/99/nm5331599_rm3975273728_1996-11-27_2013.jpg
#   inflating: imdb_crop/imdb.mat

# %%
#Load MATLAB file 'imdb.mat' using the scipy.io module.
mat = scipy.io.loadmat('imdb_crop/imdb.mat')

#Display the contents of mat variable
display(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sun Jan 17 11:30:27 2016',
#  '__version__': '1.0',
#  '__globals__': [],
#  'imdb': array([[(array([[693726, 693726, 693726, ..., 726831, 726831, 726831]]), array([[1968, 1970, 1968, ..., 2011, 2011, 2011]], dtype=uint16), array([[array(['01/nm0000001_rm124825600_1899-5-10_1968.jpg'], dtype='<U43'),
#                  array(['01/nm0000001_rm3343756032_1899-5-10_1970.jpg'], dtype='<U44'),
#                  array(['01/nm0000001_rm577153792_1899-5-10_1968.jpg'], dtype='<U43'),
#                  ...,
#                  array(['08/nm3994408_rm926592512_1989-12-29_2011.jpg'], dtype='<U44'),
#                  array(['08/nm3994408_rm943369728_1989-12-29_2011.jpg'], dtype='<U44'),
#                  array(['08/nm3994408_rm976924160_1989-12-29_2011.jpg'], dtype='<U44')]],
#                dtype=object), array([[1., 1., 1., ..., 0., 0., 0.]]), array([[array(['Fred Astaire'], dtype='<U12'),
#                  array(['Fred Astaire'], dtype='<U12'),
#                  array(['Fred Astaire'], dtype='<U12'), ...,
#                  array(['Jane Levy'], dtype='<U9'),
#                  array(['Jane Levy'], dtype='<U9'),
#                  array(['Jane Levy'], dtype='<U9')]], dtype=object), array([[array([[1072.926,  161.838, 1214.784,  303.696]]),
#                  array([[477.184, 100.352, 622.592, 245.76 ]]),
#                  array([[114.96964309, 114.96964309, 451.68657236, 451.68657236]]),
#                  ..., array([[  1,   1, 453, 640]], dtype=uint16),
#                  array([[144.75225472, 126.76472288, 305.78804127, 287.80050943]]),
#                  array([[457.524,  41.748, 518.016, 102.24 ]])]], dtype=object), array([[1.45969291, 2.5431976 , 3.45557949, ...,       -inf, 4.45072452,
#                  2.13350269]]), array([[1.11897336, 1.85200773, 2.98566022, ...,        nan,        nan,
#                         nan]]), array([[array(["'Lee' George Quinones"], dtype='<U21'),
#                  array(["'Weird Al' Yankovic"], dtype='<U19'),
#                  array(['2 Chainz'], dtype='<U8'), ...,
#                  array(['Éric Caravaca'], dtype='<U13'),
#                  array(['Ólafur Darri Ólafsson'], dtype='<U21'),
#                  array(['Óscar Jaenada'], dtype='<U13')]], dtype=object), array([[6488, 6488, 6488, ..., 8410, 8410, 8410]], dtype=uint16))                                                                              ]],
#        dtype=[('dob', 'O'), ('photo_taken', 'O'), ('full_path', 'O'), ('gender', 'O'), ('name', 'O'), ('face_location', 'O'), ('face_score', 'O'), ('second_face_score', 'O'), ('celeb_names', 'O'), ('celeb_id', 'O')])}

# %%
# Convert the data into a pandas dataframe for easier handling and analysis

# Extract the data from the 'imdb' key in the provided data
imdb_data = mat['imdb'][0][0][0]

# Get the number of instances in the data
instances = imdb_data.shape[1]

# Define the column names for the dataframe
columns = ["dob", "photo_taken", "full_path", "gender", "name", "face_location", "face_score", "second_face_score"]

# Create an empty dataframe with the specified columns and number of instances
df = pd.DataFrame(index=range(instances), columns=columns)

# Extract the data from "imdb" key in the loaded data
current_array = mat["imdb"][0][0]

# Assign the values from the current_array to the corresponding columns in the dataframe
for j, column in enumerate(columns[:len(current_array)]):
    df[column] = pd.DataFrame(current_array[j][0])

# %%
# 1.  Converting MATLAB datenum values in the 'dob' column of the DataFrame 'df' to exact dates and calculating the corresponding years for 'date_of_birth',
# followed by calculating the age by subtracting 'date_of_birth' from the 'photo_taken' column.
from datetime import datetime, timedelta
import pandas as pd

def datenum_to_year(datenum):
    epoch = datetime(1, 1, 1)  # Define the epoch as January 1, 0001
    ordinal = int(datenum) + 366  # Adjust for MATLAB datenum offset
    exact_date = datetime.fromordinal(ordinal) + timedelta(days=datenum % 1)  # Add fractional days
    return exact_date.year

# Convert MATLAB datenum values to years and assign the result to the 'date_of_birth' column
df['date_of_birth'] = df['dob'].apply(datenum_to_year)

# 2.  Calculate the age by subtracting 'date_of_birth' from the 'photo_taken' column
df['age'] = df['photo_taken'] - df['date_of_birth']

# %%
# 3.  Removing pictures that don't have faces based on the 'face_score' column
df = df.loc[df['face_score'] != -np.inf]

# 4.  Removing duplicate pictures based on the presence of a second face ('second_face_score' is NaN)
df = df.loc[df['second_face_score'].isna()]

# 5.  Removing pictures with age greater than 100 or less than or equal to 0
df = df.loc[df['age'] <= 100]
df = df.loc[df['age'] > 0]

# %%
# 6.  Droping rows with missing values in the 'gender' column
df.dropna(subset=['gender'], inplace=True)

# Displaying the value counts of the 'gender' column using value_counts() to understand the distribution of genders in the dataset.
gender_counts = df['gender'].value_counts()
display(gender_counts)

# NOTE: Gender: 1 - Male , 0 - Female
# Out:
# 1.0    99875
# 0.0    81520
# Name: gender, dtype: int64

# %%
# 7.  Filtering the DataFrame df based on a 'face_score' threshold of 1.5, removing rows with lower-quality face images.
df = df[df['face_score'] >= 1.5]

# %%
# 8. Converting each element in the 'full_path' column to a string by using str() and np.squeeze() within a list comprehension,
# the code assigns the resulting string representations to a new 'path' column in the DataFrame.
df['path'] = [str(np.squeeze(i)) for i in df['full_path']]
display(df)
# Out:
#            dob  photo_taken                                       full_path  \
# 3       693726         1968   [01/nm0000001_rm946909184_1899-5-10_1968.jpg]
# 6       702986         2004  [02/nm0000002_rm1346607872_1924-9-16_2004.jpg]
# 7       702986         2004  [02/nm0000002_rm1363385088_1924-9-16_2004.jpg]
# 12      702986         1974   [02/nm0000002_rm221957120_1924-9-16_1974.jpg]
# 13      702986         2007  [02/nm0000002_rm2287049216_1924-9-16_2007.jpg]
# ...        ...          ...                                             ...
# 460715  726831         2011   [08/nm3994408_rm73386752_1989-12-29_2011.jpg]
# 460716  726831         2011  [08/nm3994408_rm744468480_1989-12-29_2011.jpg]
# 460718  726831         2011  [08/nm3994408_rm761245696_1989-12-29_2011.jpg]
# 460721  726831         2011  [08/nm3994408_rm943369728_1989-12-29_2011.jpg]
# 460722  726831         2011  [08/nm3994408_rm976924160_1989-12-29_2011.jpg]
#
#         gender             name  \
# 3          1.0   [Fred Astaire]
# 6          0.0  [Lauren Bacall]
# 7          0.0  [Lauren Bacall]
# 12         0.0  [Lauren Bacall]
# 13         0.0  [Lauren Bacall]
# ...        ...              ...
# 460715     0.0      [Jane Levy]
# 460716     0.0      [Jane Levy]
# 460718     0.0      [Jane Levy]
# 460721     0.0      [Jane Levy]
# 460722     0.0      [Jane Levy]
#
#                                             face_location  face_score  \
# 3       [[622.8855056426588, 424.21750383700805, 844.3...    1.872117
# 6       [[78.23569406558903, 52.335129377059346, 194.2...    3.479189
# 7       [[64.30867103752385, 64.30867103752385, 207.26...    3.870171
# 12      [[3173.144692593433, 401.0408365741791, 4059.1...    4.096431
# 13      [[138.80620247948153, 33.92673852953003, 181.1...    3.482030
# ...                                                   ...         ...
# 460715                             [[161, 161, 448, 448]]    4.801987
# 460716              [[300.756, 96.276, 422.592, 218.112]]    2.370091
# 460718  [[453.8981431333457, 77.96623712908011, 539.79...    3.845884
# 460721  [[144.75225471724875, 126.76472287759263, 305....    4.450725
# 460722               [[457.524, 41.748, 518.016, 102.24]]    2.133503
#
#         second_face_score  date_of_birth  age  \
# 3                     NaN           1901   67
# 6                     NaN           1926   78
# 7                     NaN           1926   78
# 12                    NaN           1926   48
# 13                    NaN           1926   81
# ...                   ...            ...  ...
# 460715                NaN           1991   20
# 460716                NaN           1991   20
# 460718                NaN           1991   20
# 460721                NaN           1991   20
# 460722                NaN           1991   20
#
#                                                 path
# 3        01/nm0000001_rm946909184_1899-5-10_1968.jpg
# 6       02/nm0000002_rm1346607872_1924-9-16_2004.jpg
# 7       02/nm0000002_rm1363385088_1924-9-16_2004.jpg
# 12       02/nm0000002_rm221957120_1924-9-16_1974.jpg
# 13      02/nm0000002_rm2287049216_1924-9-16_2007.jpg
# ...                                              ...
# 460715   08/nm3994408_rm73386752_1989-12-29_2011.jpg
# 460716  08/nm3994408_rm744468480_1989-12-29_2011.jpg
# 460718  08/nm3994408_rm761245696_1989-12-29_2011.jpg
# 460721  08/nm3994408_rm943369728_1989-12-29_2011.jpg
# 460722  08/nm3994408_rm976924160_1989-12-29_2011.jpg
#
# [153626 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153626 entries, 3 to 460722
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dob                153626 non-null  int32
#  1   photo_taken        153626 non-null  uint16
#  2   full_path          153626 non-null  object
#  3   gender             153626 non-null  float64
#  4   name               153626 non-null  object
#  5   face_location      153626 non-null  object
#  6   face_score         153626 non-null  float64
#  7   second_face_score  0 non-null       float64
#  8   date_of_birth      153626 non-null  int64
#  9   age                153626 non-null  int64
#  10  path               153626 non-null  object
# dtypes: float64(3), int32(1), int64(2), object(4), uint16(1)
# memory usage: 12.6+ MB

# %%
# Defining a function to return the class labels corresponding to the re-distributed 7 age-ranges.
def class_labels_reassign(age):
    if 1 <= age <= 2:
        return 0
    elif 3 <= age <= 9:
        return 1
    elif 10 <= age <= 20:
        return 2
    elif 21 <= age <= 27:
        return 3
    elif 28 <= age <= 45:
        return 4
    elif 46 <= age <= 65:
        return 5
    else:
        return 6

#train_aug_df['target'] = train_aug_df['age'].map(class_labels_reassign)
#test_df['target'] = test_df['age'].map(class_labels_reassign)
df['target'] = df['age'].map(class_labels_reassign)

# %%
# Shuffling the DataFrame 'df' and creating a new DataFrame 'df_trial' containing half of the shuffled data, rounding the number of rows if needed.
df = shuffle(df)
df_trial = df[:round(df.shape[0]*0.5)]

# Splitting the shuffled DataFrame 'df_trial' into 'train' and 'val' DataFrames, with approximately 70% for training and 30% for validation.
train = df_trial[:round(df_trial.shape[0]*0.7)]
val = df_trial[round(df_trial.shape[0]*0.7):]

# Printing the number of rows and columns in the 'train' and 'val' DataFrames, respectively.
print(train.shape)
print(val.shape)
# Out:
# (53769, 12)
# (23044, 12)

# %%
# Converting the filenames and target class labels into lists for augmented train and test datasets.
train_aug_filenames_list = list(train['path'])
train_aug_labels_list = list(train['target'])
test_filenames_list = list(val['path'])
test_labels_list = list(val['target'])

# Creating tensorflow constants of filenames and labels for augmented train and test datasets from the lists defined above.
train_aug_filenames_tensor = tf.constant(train_aug_filenames_list)
train_aug_labels_tensor = tf.constant(train_aug_labels_list)
test_filenames_tensor = tf.constant(test_filenames_list)
test_labels_tensor = tf.constant(test_labels_list)

# %%
# Defining a function to read the image, decode the image from given tensor and one-hot encode the image label class.
# Changing the channels para in tf.io.decode_jpeg from 3 to 1 changes the output images from RGB coloured to grayscale.
num_classes = 7
def _parse_function(path, label):
    image_string = tf.io.read_file("D:/Users/ndhu2/Classes/Introduction to AI/Project/imdb_crop/"+path)
    image_decoded = tf.io.decode_jpeg(image_string, channels=1)    # channels=1 to convert to grayscale, channels=3 to convert to RGB.
    image_resized = tf.image.resize_with_pad(image_decoded, 200, 200)
    label = tf.one_hot(label, num_classes)
    return image_resized, label


# Getting the dataset ready for the neural network.
# Using the tensor vectors defined above, accessing the images in the dataset and passing them through the function defined above.
train_aug_dataset = tf.data.Dataset.from_tensor_slices((train_aug_filenames_tensor, train_aug_labels_tensor))
train_aug_dataset = train_aug_dataset.map(_parse_function)
# train_aug_dataset = train_aug_dataset.repeat(3)
train_aug_dataset = train_aug_dataset.batch(256)    # Same as batch_size hyperparameter in model.fit() below.

test_dataset = tf.data.Dataset.from_tensor_slices((test_filenames_tensor, test_labels_tensor))
test_dataset = test_dataset.map(_parse_function)
# test_dataset = test_dataset.repeat(3)
test_dataset = test_dataset.batch(256)    # Same as batch_size hyperparameter in model.fit() below.

# %%
# Defining the architecture of the sequential neural network.
final_cnn = Sequential()
# Input layer with 32 filters, followed by an AveragePooling2D layer.
final_cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=(200, 200, 1)))    # 3rd dim = 1 for grayscale images.
final_cnn.add(AveragePooling2D(pool_size=(2,2)))
# Three Conv2D layers with filters increasing by a factor of 2 for every successive Conv2D layer.
final_cnn.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
final_cnn.add(AveragePooling2D(pool_size=(2,2)))
final_cnn.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
final_cnn.add(AveragePooling2D(pool_size=(2,2)))
final_cnn.add(Conv2D(filters=256, kernel_size=3, activation='relu'))
final_cnn.add(AveragePooling2D(pool_size=(2,2)))
# A GlobalAveragePooling2D layer before going into Dense layers below.
# GlobalAveragePooling2D layer gives no. of outputs equal to no. of filters in last Conv2D layer above (256).
final_cnn.add(GlobalAveragePooling2D())
# One Dense layer with 132 nodes so as to taper down the no. of nodes from no. of outputs of GlobalAveragePooling2D layer above towards no. of nodes in output layer below (7).
final_cnn.add(Dense(132, activation='relu'))
# Output layer with 7 nodes (equal to the no. of classes).
final_cnn.add(Dense(7, activation='softmax'))
final_cnn.summary()

# Compiling the above created CNN architecture.
final_cnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Creating a TensorBoard callback object and saving it at the desired location.
tensorboard = TensorBoard(log_dir=f"D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 198, 198, 32)      320
#
#  average_pooling2d_12 (Aver  (None, 99, 99, 32)        0
#  agePooling2D)
#
#  conv2d_13 (Conv2D)          (None, 97, 97, 64)        18496
#
#  average_pooling2d_13 (Aver  (None, 48, 48, 64)        0
#  agePooling2D)
#
#  conv2d_14 (Conv2D)          (None, 46, 46, 128)       73856
#
#  average_pooling2d_14 (Aver  (None, 23, 23, 128)       0
#  agePooling2D)
#
#  conv2d_15 (Conv2D)          (None, 21, 21, 256)       295168
#
#  average_pooling2d_15 (Aver  (None, 10, 10, 256)       0
#  agePooling2D)
#
#  global_average_pooling2d_3  (None, 256)               0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 132)               33924
#
#  dense_7 (Dense)             (None, 7)                 931
#
# =================================================================
# Total params: 422695 (1.61 MB)
# Trainable params: 422695 (1.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Creating a ModelCheckpoint callback object to save the model according to the value of val_accuracy.

checkpoint = ModelCheckpoint(filepath=f"D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs/age_model_checkpoint.h5",
                             monitor='val_accuracy',
                             save_best_only=True,
                             save_weights_only=False,
                             verbose=1
                            )

# Fitting the above created CNN model.
final_cnn_history = final_cnn.fit(train_aug_dataset,
                                  batch_size=256,
                                  validation_data=test_dataset,
                                  epochs=10,
                                  callbacks=[tensorboard, checkpoint],
                                  shuffle=False    # shuffle=False to reduce randomness and increase reproducibility
                                 )
# Out:
# Epoch 1/10
# 211/211 [==============================] - ETA: 0s - loss: 1.3994 - accuracy: 0.5040
# Epoch 1: val_accuracy improved from -inf to 0.51055, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs\age_model_checkpoint.h5
# 211/211 [==============================] - 1948s 9s/step - loss: 1.3994 - accuracy: 0.5040 - val_loss: 1.3181 - val_accuracy: 0.5105
# Epoch 2/10
# c:\Users\ndhu2\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 211/211 [==============================] - ETA: 0s - loss: 1.3238 - accuracy: 0.5102
# Epoch 2: val_accuracy did not improve from 0.51055
# 211/211 [==============================] - 2021s 10s/step - loss: 1.3238 - accuracy: 0.5102 - val_loss: 1.3169 - val_accuracy: 0.5105
# Epoch 3/10
# 211/211 [==============================] - ETA: 0s - loss: 1.3082 - accuracy: 0.5101
# Epoch 3: val_accuracy improved from 0.51055 to 0.51068, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs\age_model_checkpoint.h5
# 211/211 [==============================] - 923s 4s/step - loss: 1.3082 - accuracy: 0.5101 - val_loss: 1.3187 - val_accuracy: 0.5107
# Epoch 4/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2993 - accuracy: 0.5104
# Epoch 4: val_accuracy improved from 0.51068 to 0.51076, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs\age_model_checkpoint.h5
# 211/211 [==============================] - 903s 4s/step - loss: 1.2993 - accuracy: 0.5104 - val_loss: 1.2959 - val_accuracy: 0.5108
# Epoch 5/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2888 - accuracy: 0.5110
# Epoch 5: val_accuracy did not improve from 0.51076
# 211/211 [==============================] - 877s 4s/step - loss: 1.2888 - accuracy: 0.5110 - val_loss: 1.2939 - val_accuracy: 0.5105
# Epoch 6/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2780 - accuracy: 0.5112
# Epoch 6: val_accuracy did not improve from 0.51076
# 211/211 [==============================] - 877s 4s/step - loss: 1.2780 - accuracy: 0.5112 - val_loss: 1.2815 - val_accuracy: 0.5107
# Epoch 7/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2676 - accuracy: 0.5124
# Epoch 7: val_accuracy did not improve from 0.51076
# 211/211 [==============================] - 884s 4s/step - loss: 1.2676 - accuracy: 0.5124 - val_loss: 1.2798 - val_accuracy: 0.5078
# Epoch 8/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2533 - accuracy: 0.5135
# Epoch 8: val_accuracy improved from 0.51076 to 0.51245, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs\age_model_checkpoint.h5
# 211/211 [==============================] - 883s 4s/step - loss: 1.2533 - accuracy: 0.5135 - val_loss: 1.2537 - val_accuracy: 0.5125
# Epoch 9/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2378 - accuracy: 0.5146
# Epoch 9: val_accuracy did not improve from 0.51245
# 211/211 [==============================] - 976s 5s/step - loss: 1.2378 - accuracy: 0.5146 - val_loss: 1.2431 - val_accuracy: 0.5117
# Epoch 10/10
# 211/211 [==============================] - ETA: 0s - loss: 1.2186 - accuracy: 0.5187
# Epoch 10: val_accuracy did not improve from 0.51245
# 211/211 [==============================] - 1202s 6s/step - loss: 1.2186 - accuracy: 0.5187 - val_loss: 1.2670 - val_accuracy: 0.4991

# %%
# Checking the train and test loss and accuracy values from the neural network above.
train_loss = final_cnn_history.history['loss']
test_loss = final_cnn_history.history['val_loss']
train_accuracy = final_cnn_history.history['accuracy']
test_accuracy = final_cnn_history.history['val_accuracy']

# Plotting a line chart to visualize the loss and accuracy values by epochs.
fig, ax = plt.subplots(ncols=2, figsize=(15,7))
ax = ax.ravel()
ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)
ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)
ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)
ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)
ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)
ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)
fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)


# Exporting plot image in PNG format.
plt.savefig('D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs/final_cnn_loss_accuracy.png', bbox_inches='tight');

# %%
# Evaluating the model on test dataset.
final_cnn_score = final_cnn.evaluate(test_dataset, verbose=1)
# Printing the relevant score summary.
final_cnn_labels = final_cnn.metrics_names
print(f'CNN model {final_cnn_labels[0]} \t\t= {round(final_cnn_score[0], 3)}')
print(f'CNN model {final_cnn_labels[1]} \t= {round(final_cnn_score[1], 3)}')

# Saving the model as a h5 file for possible use later.
final_cnn.save(f"D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/age_model_acc_{round(final_cnn_score[1], 3)}.h5", save_format='h5')

# Generating predictions from the model above.
final_cnn_pred = final_cnn.predict(test_dataset)
final_cnn_pred = final_cnn_pred.argmax(axis=-1)
# Generating a confusion matrix based on above predictions.
conf_mat = confusion_matrix(test_labels_list, final_cnn_pred)

# Defining a function to plot the confusion matrix in a grid for easier visualization.
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', export_as='confusion_matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    # print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=16)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True labels', fontsize=14)
    plt.xlabel('Predicted labels', fontsize=14)
    # Exporting plot image in PNG format.
    plt.savefig(f'D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/M4/cnn_logs/{export_as}.png', bbox_inches='tight');

# Plotting the confusion matrix using the function defined above.
cm_plot_labels = ['1-2', '3-9', '10-20', '21-27', '28-45', '46-65', '66-116']
plt.figure(figsize=(16,8))
plot_confusion_matrix(conf_mat, cm_plot_labels, normalize=True,
                      title="Confusion Matrix based on predictions from CNN model",
                      export_as="final_cnn_conf_mat_norm"
                     )
plt.show()
# Out:
# 91/91 [==============================] - 85s 938ms/step - loss: 1.2670 - accuracy: 0.4991
# CNN model loss 		= 1.267
# CNN model accuracy 	= 0.499
# 91/91 [==============================] - 93s 1s/step
# Normalized confusion matrix

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# This function is used to load an image from a given file path, making it suitable for machine learning algorithms by resizing, converting, and normalizing the image.
def loadImage(filepath):
    test_img = image.load_img(filepath, target_size=(200, 200), color_mode="grayscale")
    test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis=0)
    test_img /= 255
    return test_img

# Load and preprocess the image using the loadImage function
desired_path = 'D:/Users/ndhu2/Classes/Introduction to AI/Project/imdb_crop/08/nm3994408_rm73386752_1989-12-29_2011.jpg'
img_resized = loadImage(desired_path)

# Predicting the age estimation for the image loaded using the loadImage function and stored in the variable img_resized.
prediction = final_cnn.predict(img_resized)
print("Prediction:", np.argmax(prediction))

# Filter the DataFrame to get the desired record
desired_path = '08/nm3994408_rm73386752_1989-12-29_2011.jpg'
filtered_df = df[df['path'] == desired_path]

if not filtered_df.empty:
    # If you want to get all features of the record:
    record_features = filtered_df.iloc[0]  # Select the first row as a Series

    # If you want to get the 'age' and 'path' values separately:
    age_value = filtered_df['age'].iloc[0]
    path_value = filtered_df['path'].iloc[0]

    # Display the result
    print("All Features of the Record:")
    print(record_features)

    print("\nAge Value of the Record:", age_value)
    print("Path Value of the Record:", path_value)
else:
    print("No record found with the desired path:", desired_path)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Prediction: 4
# All Features of the Record:
# dob                                                         726831
# photo_taken                                                   2011
# full_path            [08/nm3994408_rm73386752_1989-12-29_2011.jpg]
# gender                                                         0.0
# name                                                   [Jane Levy]
# face_location                               [[161, 161, 448, 448]]
# face_score                                                4.801987
# second_face_score                                              NaN
# date_of_birth                                                 1991
# age                                                             20
# path                   08/nm3994408_rm73386752_1989-12-29_2011.jpg
# target                                                           2
# Name: 460715, dtype: object
#
# Age Value of the Record: 20
# Path Value of the Record: 08/nm3994408_rm73386752_1989-12-29_2011.jpg
