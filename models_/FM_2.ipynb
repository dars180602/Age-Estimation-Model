# %%
# Untitled 5 but using a different architecture and augmentations
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import itertools
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Dense, BatchNormalization, concatenate
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.utils import shuffle
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model

# Setting random seeds to reduce the amount of randomness in the neural net weights and results
# The results may still not be exactly reproducible
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# C:\Users\ndhu2\AppData\Local\Temp\ipykernel_28104\1215708746.py:24: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
#Load MATLAB file 'imdb.mat' using the scipy.io module.
mat = scipy.io.loadmat('imdb_crop/imdb.mat')

#Display the contents of mat variable
display(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sun Jan 17 11:30:27 2016',
#  '__version__': '1.0',
#  '__globals__': [],
#  'imdb': array([[(array([[693726, 693726, 693726, ..., 726831, 726831, 726831]]), array([[1968, 1970, 1968, ..., 2011, 2011, 2011]], dtype=uint16), array([[array(['01/nm0000001_rm124825600_1899-5-10_1968.jpg'], dtype='<U43'),
#                  array(['01/nm0000001_rm3343756032_1899-5-10_1970.jpg'], dtype='<U44'),
#                  array(['01/nm0000001_rm577153792_1899-5-10_1968.jpg'], dtype='<U43'),
#                  ...,
#                  array(['08/nm3994408_rm926592512_1989-12-29_2011.jpg'], dtype='<U44'),
#                  array(['08/nm3994408_rm943369728_1989-12-29_2011.jpg'], dtype='<U44'),
#                  array(['08/nm3994408_rm976924160_1989-12-29_2011.jpg'], dtype='<U44')]],
#                dtype=object), array([[1., 1., 1., ..., 0., 0., 0.]]), array([[array(['Fred Astaire'], dtype='<U12'),
#                  array(['Fred Astaire'], dtype='<U12'),
#                  array(['Fred Astaire'], dtype='<U12'), ...,
#                  array(['Jane Levy'], dtype='<U9'),
#                  array(['Jane Levy'], dtype='<U9'),
#                  array(['Jane Levy'], dtype='<U9')]], dtype=object), array([[array([[1072.926,  161.838, 1214.784,  303.696]]),
#                  array([[477.184, 100.352, 622.592, 245.76 ]]),
#                  array([[114.96964309, 114.96964309, 451.68657236, 451.68657236]]),
#                  ..., array([[  1,   1, 453, 640]], dtype=uint16),
#                  array([[144.75225472, 126.76472288, 305.78804127, 287.80050943]]),
#                  array([[457.524,  41.748, 518.016, 102.24 ]])]], dtype=object), array([[1.45969291, 2.5431976 , 3.45557949, ...,       -inf, 4.45072452,
#                  2.13350269]]), array([[1.11897336, 1.85200773, 2.98566022, ...,        nan,        nan,
#                         nan]]), array([[array(["'Lee' George Quinones"], dtype='<U21'),
#                  array(["'Weird Al' Yankovic"], dtype='<U19'),
#                  array(['2 Chainz'], dtype='<U8'), ...,
#                  array(['Éric Caravaca'], dtype='<U13'),
#                  array(['Ólafur Darri Ólafsson'], dtype='<U21'),
#                  array(['Óscar Jaenada'], dtype='<U13')]], dtype=object), array([[6488, 6488, 6488, ..., 8410, 8410, 8410]], dtype=uint16))                                                                              ]],
#        dtype=[('dob', 'O'), ('photo_taken', 'O'), ('full_path', 'O'), ('gender', 'O'), ('name', 'O'), ('face_location', 'O'), ('face_score', 'O'), ('second_face_score', 'O'), ('celeb_names', 'O'), ('celeb_id', 'O')])}

# %%
# Convert the data into a pandas dataframe for easier handling and analysis

# Extract the data from the 'imdb' key in the provided data
imdb_data = mat['imdb'][0][0][0]

# Get the number of instances in the data
instances = imdb_data.shape[1]

# Define the column names for the dataframe
columns = ["dob", "photo_taken", "full_path", "gender", "name", "face_location", "face_score", "second_face_score"]

# Create an empty dataframe with the specified columns and number of instances
df = pd.DataFrame(index=range(instances), columns=columns)

# Extract the data from "imdb" key in the loaded data
current_array = mat["imdb"][0][0]

# Assign the values from the current_array to the corresponding columns in the dataframe
for j, column in enumerate(columns[:len(current_array)]):
    df[column] = pd.DataFrame(current_array[j][0])

# %%
# 1.  Converting MATLAB datenum values in the 'dob' column of the DataFrame 'df' to exact dates and calculating the corresponding years for 'date_of_birth',
# followed by calculating the age by subtracting 'date_of_birth' from the 'photo_taken' column.
from datetime import datetime, timedelta

def datenum_to_year(datenum):
    epoch = datetime(1, 1, 1)  # Define the epoch as January 1, 0001
    ordinal = int(datenum) + 366  # Adjust for MATLAB datenum offset
    exact_date = datetime.fromordinal(ordinal) + timedelta(days=datenum % 1)  # Add fractional days
    return exact_date.year

# Convert MATLAB datenum values to years and assign the result to the 'date_of_birth' column
df['date_of_birth'] = df['dob'].apply(datenum_to_year)

# 2.  Calculate the age by subtracting 'date_of_birth' from the 'photo_taken' column
df['age'] = df['photo_taken'] - df['date_of_birth']

# %%
# 3.  Removing pictures that don't have faces based on the 'face_score' column
df = df.loc[df['face_score'] != -np.inf]

# 4.  Removing duplicate pictures based on the presence of a second face ('second_face_score' is NaN)
df = df.loc[df['second_face_score'].isna()]

# 5.  Removing pictures with age greater than 100 or less than or equal to 0
df = df.loc[df['age'] <= 100]
df = df.loc[df['age'] > 0]

# %%
# 6.  Droping rows with missing values in the 'gender' column
df.dropna(subset=['gender'], inplace=True)

# Displaying the value counts of the 'gender' column using value_counts() to understand the distribution of genders in the dataset.
gender_counts = df['gender'].value_counts()
display(gender_counts)

# NOTE: Gender: 1 - Male , 0 - Female
# Out:
# 1.0    99875
# 0.0    81520
# Name: gender, dtype: int64

# %%
# 7.  Filtering the DataFrame df based on a 'face_score' threshold of 1.5, removing rows with lower-quality face images.
df = df[df['face_score'] >= 1.5]

# %%
# 8. Converting each element in the 'full_path' column to a string by using str() and np.squeeze() within a list comprehension,
# the code assigns the resulting string representations to a new 'path' column in the DataFrame.
df['path'] = [str(np.squeeze(i)) for i in df['full_path']]
display(df)
# Out:
#            dob  photo_taken                                       full_path  \
# 3       693726         1968   [01/nm0000001_rm946909184_1899-5-10_1968.jpg]
# 6       702986         2004  [02/nm0000002_rm1346607872_1924-9-16_2004.jpg]
# 7       702986         2004  [02/nm0000002_rm1363385088_1924-9-16_2004.jpg]
# 12      702986         1974   [02/nm0000002_rm221957120_1924-9-16_1974.jpg]
# 13      702986         2007  [02/nm0000002_rm2287049216_1924-9-16_2007.jpg]
# ...        ...          ...                                             ...
# 460715  726831         2011   [08/nm3994408_rm73386752_1989-12-29_2011.jpg]
# 460716  726831         2011  [08/nm3994408_rm744468480_1989-12-29_2011.jpg]
# 460718  726831         2011  [08/nm3994408_rm761245696_1989-12-29_2011.jpg]
# 460721  726831         2011  [08/nm3994408_rm943369728_1989-12-29_2011.jpg]
# 460722  726831         2011  [08/nm3994408_rm976924160_1989-12-29_2011.jpg]
#
#         gender             name  \
# 3          1.0   [Fred Astaire]
# 6          0.0  [Lauren Bacall]
# 7          0.0  [Lauren Bacall]
# 12         0.0  [Lauren Bacall]
# 13         0.0  [Lauren Bacall]
# ...        ...              ...
# 460715     0.0      [Jane Levy]
# 460716     0.0      [Jane Levy]
# 460718     0.0      [Jane Levy]
# 460721     0.0      [Jane Levy]
# 460722     0.0      [Jane Levy]
#
#                                             face_location  face_score  \
# 3       [[622.8855056426588, 424.21750383700805, 844.3...    1.872117
# 6       [[78.23569406558903, 52.335129377059346, 194.2...    3.479189
# 7       [[64.30867103752385, 64.30867103752385, 207.26...    3.870171
# 12      [[3173.144692593433, 401.0408365741791, 4059.1...    4.096431
# 13      [[138.80620247948153, 33.92673852953003, 181.1...    3.482030
# ...                                                   ...         ...
# 460715                             [[161, 161, 448, 448]]    4.801987
# 460716              [[300.756, 96.276, 422.592, 218.112]]    2.370091
# 460718  [[453.8981431333457, 77.96623712908011, 539.79...    3.845884
# 460721  [[144.75225471724875, 126.76472287759263, 305....    4.450725
# 460722               [[457.524, 41.748, 518.016, 102.24]]    2.133503
#
#         second_face_score  date_of_birth  age  \
# 3                     NaN           1901   67
# 6                     NaN           1926   78
# 7                     NaN           1926   78
# 12                    NaN           1926   48
# 13                    NaN           1926   81
# ...                   ...            ...  ...
# 460715                NaN           1991   20
# 460716                NaN           1991   20
# 460718                NaN           1991   20
# 460721                NaN           1991   20
# 460722                NaN           1991   20
#
#                                                 path
# 3        01/nm0000001_rm946909184_1899-5-10_1968.jpg
# 6       02/nm0000002_rm1346607872_1924-9-16_2004.jpg
# 7       02/nm0000002_rm1363385088_1924-9-16_2004.jpg
# 12       02/nm0000002_rm221957120_1924-9-16_1974.jpg
# 13      02/nm0000002_rm2287049216_1924-9-16_2007.jpg
# ...                                              ...
# 460715   08/nm3994408_rm73386752_1989-12-29_2011.jpg
# 460716  08/nm3994408_rm744468480_1989-12-29_2011.jpg
# 460718  08/nm3994408_rm761245696_1989-12-29_2011.jpg
# 460721  08/nm3994408_rm943369728_1989-12-29_2011.jpg
# 460722  08/nm3994408_rm976924160_1989-12-29_2011.jpg
#
# [153626 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153626 entries, 3 to 460722
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dob                153626 non-null  int32
#  1   photo_taken        153626 non-null  uint16
#  2   full_path          153626 non-null  object
#  3   gender             153626 non-null  float64
#  4   name               153626 non-null  object
#  5   face_location      153626 non-null  object
#  6   face_score         153626 non-null  float64
#  7   second_face_score  0 non-null       float64
#  8   date_of_birth      153626 non-null  int64
#  9   age                153626 non-null  int64
#  10  path               153626 non-null  object
# dtypes: float64(3), int32(1), int64(2), object(4), uint16(1)
# memory usage: 12.6+ MB

# %%
folder_path = 'D:/Users/ndhu2/Classes/Introduction to AI/Project/imdb_crop/crop_part1'  # Replace with the actual folder path

# Step 1: Use os.listdir to get a list of all image filenames in the folder
image_filenames = os.listdir(folder_path)

# Initialize an empty list to store individual DataFrames
dataframes_list = []

# Step 2: Loop through the filenames and extract age and gender information
for filename in image_filenames:
    # Split the filename using underscores to get age, gender, and other parts
    parts = filename.split('_')
    age = int(parts[0])
    gender = int(parts[1])

    # Create the full path to the image file
    image_path = 'crop_part1/'+filename

    # Step 3: Create a DataFrame for the current image and append it to the list
    image_df = pd.DataFrame({'path': [image_path], 'age': [age], 'gender': [gender]})
    dataframes_list.append(image_df)

temp_df = pd.concat(dataframes_list, ignore_index=True)

# Step 4: Concatenate all individual DataFrames into the final DataFrame
df = pd.concat([df, temp_df], ignore_index=True)

# Your DataFrame 'df' now contains the path, age, and gender information of the images
print(df.head())  # Check the first few rows of the DataFrame
# Out:
#         dob  photo_taken                                       full_path  \
# 0  693726.0       1968.0   [01/nm0000001_rm946909184_1899-5-10_1968.jpg]
# 1  702986.0       2004.0  [02/nm0000002_rm1346607872_1924-9-16_2004.jpg]
# 2  702986.0       2004.0  [02/nm0000002_rm1363385088_1924-9-16_2004.jpg]
# 3  702986.0       1974.0   [02/nm0000002_rm221957120_1924-9-16_1974.jpg]
# 4  702986.0       2007.0  [02/nm0000002_rm2287049216_1924-9-16_2007.jpg]
#
#    gender             name                                      face_location  \
# 0     1.0   [Fred Astaire]  [[622.8855056426588, 424.21750383700805, 844.3...
# 1     0.0  [Lauren Bacall]  [[78.23569406558903, 52.335129377059346, 194.2...
# 2     0.0  [Lauren Bacall]  [[64.30867103752385, 64.30867103752385, 207.26...
# 3     0.0  [Lauren Bacall]  [[3173.144692593433, 401.0408365741791, 4059.1...
# 4     0.0  [Lauren Bacall]  [[138.80620247948153, 33.92673852953003, 181.1...
#
#    face_score  second_face_score  date_of_birth  age  \
# 0    1.872117                NaN         1901.0   67
# 1    3.479189                NaN         1926.0   78
# 2    3.870171                NaN         1926.0   78
# 3    4.096431                NaN         1926.0   48
# 4    3.482030                NaN         1926.0   81
#
#                                            path
# 0   01/nm0000001_rm946909184_1899-5-10_1968.jpg
# 1  02/nm0000002_rm1346607872_1924-9-16_2004.jpg
# 2  02/nm0000002_rm1363385088_1924-9-16_2004.jpg
# 3   02/nm0000002_rm221957120_1924-9-16_1974.jpg
# 4  02/nm0000002_rm2287049216_1924-9-16_2007.jpg

# %%
folder_path = 'D:/Users/ndhu2/Classes/Introduction to AI/Project/imdb_crop/UTKFace'  # Replace with the actual folder path

# Step 1: Use os.listdir to get a list of all image filenames in the folder
image_filenames = os.listdir(folder_path)

# Initialize an empty list to store individual DataFrames
dataframes_list = []

# Step 2: Loop through the filenames and extract age and gender information
for filename in image_filenames:
    # Split the filename using underscores to get age, gender, and other parts
    parts = filename.split('_')
    age = int(parts[0])
    gender = int(parts[1])

    # Create the full path to the image file
    image_path = 'UTKFace/'+filename

    # Step 3: Create a DataFrame for the current image and append it to the list
    image_df = pd.DataFrame({'path': [image_path], 'age': [age], 'gender': [gender]})
    dataframes_list.append(image_df)

temp_df = pd.concat(dataframes_list, ignore_index=True)

# Step 4: Concatenate all individual DataFrames into the final DataFrame
df = pd.concat([df, temp_df], ignore_index=True)

# Your DataFrame 'df' now contains the path, age, and gender information of the images
print(df.head())  # Check the first few rows of the DataFrame
# Out:
#         dob  photo_taken                                       full_path  \
# 0  693726.0       1968.0   [01/nm0000001_rm946909184_1899-5-10_1968.jpg]
# 1  702986.0       2004.0  [02/nm0000002_rm1346607872_1924-9-16_2004.jpg]
# 2  702986.0       2004.0  [02/nm0000002_rm1363385088_1924-9-16_2004.jpg]
# 3  702986.0       1974.0   [02/nm0000002_rm221957120_1924-9-16_1974.jpg]
# 4  702986.0       2007.0  [02/nm0000002_rm2287049216_1924-9-16_2007.jpg]
#
#    gender             name                                      face_location  \
# 0     1.0   [Fred Astaire]  [[622.8855056426588, 424.21750383700805, 844.3...
# 1     0.0  [Lauren Bacall]  [[78.23569406558903, 52.335129377059346, 194.2...
# 2     0.0  [Lauren Bacall]  [[64.30867103752385, 64.30867103752385, 207.26...
# 3     0.0  [Lauren Bacall]  [[3173.144692593433, 401.0408365741791, 4059.1...
# 4     0.0  [Lauren Bacall]  [[138.80620247948153, 33.92673852953003, 181.1...
#
#    face_score  second_face_score  date_of_birth  age  \
# 0    1.872117                NaN         1901.0   67
# 1    3.479189                NaN         1926.0   78
# 2    3.870171                NaN         1926.0   78
# 3    4.096431                NaN         1926.0   48
# 4    3.482030                NaN         1926.0   81
#
#                                            path
# 0   01/nm0000001_rm946909184_1899-5-10_1968.jpg
# 1  02/nm0000002_rm1346607872_1924-9-16_2004.jpg
# 2  02/nm0000002_rm1363385088_1924-9-16_2004.jpg
# 3   02/nm0000002_rm221957120_1924-9-16_1974.jpg
# 4  02/nm0000002_rm2287049216_1924-9-16_2007.jpg

# %%
display(df)
# Out:
#              dob  photo_taken                                       full_path  \
# 0       693726.0       1968.0   [01/nm0000001_rm946909184_1899-5-10_1968.jpg]
# 1       702986.0       2004.0  [02/nm0000002_rm1346607872_1924-9-16_2004.jpg]
# 2       702986.0       2004.0  [02/nm0000002_rm1363385088_1924-9-16_2004.jpg]
# 3       702986.0       1974.0   [02/nm0000002_rm221957120_1924-9-16_1974.jpg]
# 4       702986.0       2007.0  [02/nm0000002_rm2287049216_1924-9-16_2007.jpg]
# ...          ...          ...                                             ...
# 187109       NaN          NaN                                             NaN
# 187110       NaN          NaN                                             NaN
# 187111       NaN          NaN                                             NaN
# 187112       NaN          NaN                                             NaN
# 187113       NaN          NaN                                             NaN
#
#         gender             name  \
# 0          1.0   [Fred Astaire]
# 1          0.0  [Lauren Bacall]
# 2          0.0  [Lauren Bacall]
# 3          0.0  [Lauren Bacall]
# 4          0.0  [Lauren Bacall]
# ...        ...              ...
# 187109     1.0              NaN
# 187110     1.0              NaN
# 187111     1.0              NaN
# 187112     1.0              NaN
# 187113     1.0              NaN
#
#                                             face_location  face_score  \
# 0       [[622.8855056426588, 424.21750383700805, 844.3...    1.872117
# 1       [[78.23569406558903, 52.335129377059346, 194.2...    3.479189
# 2       [[64.30867103752385, 64.30867103752385, 207.26...    3.870171
# 3       [[3173.144692593433, 401.0408365741791, 4059.1...    4.096431
# 4       [[138.80620247948153, 33.92673852953003, 181.1...    3.482030
# ...                                                   ...         ...
# 187109                                                NaN         NaN
# 187110                                                NaN         NaN
# 187111                                                NaN         NaN
# 187112                                                NaN         NaN
# 187113                                                NaN         NaN
#
#         second_face_score  date_of_birth  age  \
# 0                     NaN         1901.0   67
# 1                     NaN         1926.0   78
# 2                     NaN         1926.0   78
# 3                     NaN         1926.0   48
# 4                     NaN         1926.0   81
# ...                   ...            ...  ...
# 187109                NaN            NaN    9
# 187110                NaN            NaN    9
# 187111                NaN            NaN    9
# 187112                NaN            NaN    9
# 187113                NaN            NaN    9
#
#                                                 path
# 0        01/nm0000001_rm946909184_1899-5-10_1968.jpg
# 1       02/nm0000002_rm1346607872_1924-9-16_2004.jpg
# 2       02/nm0000002_rm1363385088_1924-9-16_2004.jpg
# 3        02/nm0000002_rm221957120_1924-9-16_1974.jpg
# 4       02/nm0000002_rm2287049216_1924-9-16_2007.jpg
# ...                                              ...
# 187109  UTKFace/9_1_3_20161220222856346.jpg.chip.jpg
# 187110  UTKFace/9_1_3_20170104222949455.jpg.chip.jpg
# 187111  UTKFace/9_1_4_20170103200637399.jpg.chip.jpg
# 187112  UTKFace/9_1_4_20170103200814791.jpg.chip.jpg
# 187113  UTKFace/9_1_4_20170103213057382.jpg.chip.jpg
#
# [187114 rows x 11 columns]

# %%
# Convert the gender values to integers before grouping
df['gender'] = df['gender'].astype(int)

print(df.dtypes)
# Out:
# dob                  float64
# photo_taken          float64
# full_path             object
# gender                 int32
# name                  object
# face_location         object
# face_score           float64
# second_face_score    float64
# date_of_birth        float64
# age                    int64
# path                  object
# dtype: object

# %%
# Print unique values in the 'gender' column
gender_counts = df['gender'].value_counts()
print(gender_counts)

# Define the correct gender values that you want to keep
valid_genders = [0, 1]

# Filter the DataFrame to keep only the rows with valid gender values
df = df[df['gender'].isin(valid_genders)]

gender_counts = df['gender'].value_counts()
print(gender_counts)
# Out:
# 1    98622
# 0    88491
# 3        1
# Name: gender, dtype: int64
# 1    98622
# 0    88491
# Name: gender, dtype: int64

# %%
# Grouping the DataFrame 'df' by 'age' and 'gender' columns and counting the occurrences of each combination
age_groups = df.groupby(['age', 'gender']).size().unstack()

# Define custom colors for each gender category
colors = {0: '#4287f5', 1: '#f5428d'}

# Plotting the grouped data as a stacked bar chart with custom colors
age_groups.plot(kind='bar', stacked=True, figsize=(15, 6), color=[colors[col] for col in age_groups.columns])

# Adding a label to the x-axis
plt.xlabel('Age')

# Adding a label to the y-axis
plt.ylabel('Count')

# Adding a title to the plot
plt.title('Age and Gender Joint Distribution')

# Adding a legend to the plot with the title 'Gender'
plt.legend(title='Gender', labels=['Male', 'Female'])

# Displaying the plot
plt.show()

# %%
min_age = 0
max_age = 60
max_records_per_age_gender = 500

# Filter the DataFrame to keep only records within the desired age range
df_filtered = df[(df['age'] >= min_age) & (df['age'] <= max_age)]

# Calculate the target number of records for each gender
target_records_per_gender = df_filtered.groupby('gender').size().min() // 2

# Perform downsampling and create a new dataframe
downsampled_groups = df_filtered.groupby(['age', 'gender'], group_keys=False).apply(lambda group: group.sample(min(max_records_per_age_gender, len(group)), random_state=21))
df = downsampled_groups

# Group the downsampled dataframe
age_gender_groups = downsampled_groups.groupby(['age', 'gender']).size().unstack()

# Define custom colors for each gender category
colors = {0: '#4287f5', 1: '#f5428d'}

# Plotting
ax = age_gender_groups.plot(kind='bar', stacked=True, figsize=(10, 6), color=[colors[col] for col in age_gender_groups.columns])

# Adding labels and title
ax.set_xlabel('Age')
ax.set_ylabel('Count')
ax.set_title('Age and Gender Joint Distribution')
ax.legend(title='Gender')

# Displaying the plot
plt.show()

# %%
# Define the labels for the genders
gender_labels = ['Male', 'Female']

# Calculate the count of each gender category
gender_counts = df['gender'].value_counts()

# Define custom colors for the pie slices
colors = ['#4287f5', '#f5428d']

# Create a pie chart
plt.pie(gender_counts, labels=gender_labels, autopct='%1.1f%%', colors=colors, startangle=90)

# Add a title and adjust the font size
plt.title('Gender Distribution', fontsize=16)

# Display the chart
plt.show()

# %%
# Defining a function to return the class labels corresponding to the re-distributed 7 age-ranges.
def class_labels_reassign(age):
    if 1 <= age <= 12:
        return 0
    elif 13 <= age <= 18:
        return 1
    elif 19 <= age <= 30:
        return 2
    elif 31 <= age <= 42:
        return 3
    elif 43 <= age:
        return 4

#train_aug_df['target'] = train_aug_df['age'].map(class_labels_reassign)
#test_df['target'] = test_df['age'].map(class_labels_reassign)
df['target'] = df['age'].map(class_labels_reassign).astype(str)

# %%
# Shuffling the DataFrame 'df' and creating a new DataFrame 'df_trial' containing half of the shuffled data, rounding the number of rows if needed.
df_trial = shuffle(df)

# Splitting the shuffled DataFrame 'df_trial' into 'train' and 'val' DataFrames, with approximately 70% for training and 30% for validation.
train = df_trial[:round(df_trial.shape[0]*0.7)]
val = df_trial[round(df_trial.shape[0]*0.7):]

# Printing the number of rows and columns in the 'train' and 'val' DataFrames, respectively.
print(train.shape)
print(val.shape)
# Out:
# (39110, 12)
# (16761, 12)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Defining an image data generator for data augmentation during training, which includes rescaling pixel values, random rotation within 25 degrees,
# random brightness adjustment between 0.7 and 1.3, random zooming up to 50%, and horizontal flipping of images.
train_datagen=ImageDataGenerator(rescale=1./255.,
                           rotation_range=20,
                           brightness_range=[0.7,1.3],
                           width_shift_range=0.1,
                           height_shift_range=0.1,
                           horizontal_flip=True)

# Creating an image data generator for the validation data with pixel value rescaling only.
valid_datagen=ImageDataGenerator(rescale=1./255.)

# Create augmented train and test datasets
train_aug_dataset = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="D:/Users/ndhu2/Classes/Introduction to AI/Project/imdb_crop/",  # Assuming the full path is already in the 'path' column
    x_col='path',    # Column containing the filenames
    y_col='target',  # Column containing the target class labels
    target_size=(200, 200),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=128,
    shuffle=True,
    seed=42
)

test_dataset = valid_datagen.flow_from_dataframe(
    dataframe=val,
    directory="D:/Users/ndhu2/Classes/Introduction to AI/Project/imdb_crop/",  # Assuming the full path is already in the 'path' column
    x_col='path',    # Column containing the filenames
    y_col='target',  # Column containing the target class labels
    target_size=(200, 200),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=128,
    shuffle=False
)
# Out:
# Found 39110 validated image filenames belonging to 5 classes.
# Found 16761 validated image filenames belonging to 5 classes.

# %%
# Defining the architecture of the convolutional neural network.

def inception_module(x, filters):

    # 1x1 convolution followed by a 3x3 convolution branch
    conv1x1_1 = Conv2D(filters[0], (1, 1), activation='relu')(x)
    conv3x3 = Conv2D(filters[1], (3, 3), padding='same', activation='relu')(conv1x1_1)
    conv3x3 = BatchNormalization()(conv3x3)
    
    # 1x1 convolution followed by a 5x5 convolution branch
    conv1x1_2 = Conv2D(filters[2], (1, 1), activation='relu')(x)
    conv5x5 = Conv2D(filters[3], (5, 5), padding='same', activation='relu')(conv1x1_2)
    conv5x5 = BatchNormalization()(conv5x5)

    # 3x3 max pooling followed by a 1x1 convolution branch
    pool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    conv1x1_3 = Conv2D(filters[4], (1, 1), activation='relu')(pool)
    conv1x1_3 = BatchNormalization()(conv1x1_3)

    # Concatenate the branches
    inception_output = concatenate([conv3x3, conv5x5, conv1x1_3], axis=-1)
    return inception_output

# Input layer
input_layer = Input(shape=(200, 200, 1))

# First convolutional layer with batch normalization
x = Conv2D(filters=64, kernel_size=7, strides=2, activation='relu')(input_layer)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3, 3), strides=2)(x)

# Second Convolutional layer with batch normalization
x = Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3, 3), strides=2)(x)

# First inception module
x = inception_module(x, [64, 96, 64, 64, 64])

# Second inception module
x = inception_module(x, [96, 128, 96, 96, 96])

# Third inception module
x = inception_module(x, [128, 256, 128, 128, 128])

# Global average pooling
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)

# Fully connected layers for age estimation
x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)


# Output layer with 5 nodes (equal to the number of classes).
output_layer = Dense(5, activation='softmax')(x)

# Create the model
final_cnn = Model(inputs=input_layer, outputs=output_layer)

# Compiling the model
final_cnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
final_cnn.summary()

# Creating a TensorBoard callback object and saving it at the desired location.
tensorboard = TensorBoard(log_dir=f"D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 97, 97, 64)           3200      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 97, 97, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 48, 48, 64)           0         ['batch_normalization[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 128)          73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 46, 46, 128)          512       ['conv2d_1[0][0]']
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 22, 22, 128)          0         ['batch_normalization_1[0][0]'
#  g2D)                                                               ]
#
#  conv2d_2 (Conv2D)           (None, 22, 22, 64)           8256      ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)           8256      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 128)          0         ['max_pooling2d_1[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 96)           55392     ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 64)           102464    ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 22, 22, 64)           8256      ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 22, 22, 224)          0         ['conv2d_3[0][0]',
#                                                                      'conv2d_5[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 22, 22, 96)           21600     ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 22, 22, 96)           21600     ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 22, 22, 224)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 22, 22, 128)          110720    ['conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 22, 22, 96)           230496    ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 22, 22, 96)           21600     ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 22, 22, 320)          0         ['conv2d_8[0][0]',
#  )                                                                   'conv2d_10[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 22, 22, 128)          41088     ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 22, 22, 128)          41088     ['concatenate_1[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 22, 22, 320)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 22, 22, 256)          295168    ['conv2d_12[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 22, 22, 128)          409728    ['conv2d_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 22, 22, 128)          41088     ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 22, 22, 512)          0         ['conv2d_13[0][0]',
#  )                                                                   'conv2d_15[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  global_average_pooling2d (  (None, 512)                  0         ['concatenate_2[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 256)                  131328    ['dropout[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 5)                    645       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1659493 (6.33 MB)
# Trainable params: 1659109 (6.33 MB)
# Non-trainable params: 384 (1.50 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

# Creating an EarlyStopping callback object
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

# Creating a ModelCheckpoint callback object to save the model according to the value of val_accuracy.
checkpoint = ModelCheckpoint(filepath=f"D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM1/cnn_logs/age_model_checkpoint.h5",
                             monitor='val_accuracy',
                             save_best_only=True,
                             save_weights_only=False,
                             verbose=1
                            )

# Train the model with data augmentation and callbacks
final_cnn_history = final_cnn.fit(
    train_aug_dataset,
    validation_data=test_dataset,  # Use the original test_dataset for validation
    epochs=60,
    callbacks=[tensorboard, checkpoint, early_stopping]
)
# Out:
# Epoch 1/60
# 306/306 [==============================] - ETA: 0s - loss: 2.6670 - accuracy: 0.3723
# Epoch 1: val_accuracy improved from -inf to 0.33817, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1148s 4s/step - loss: 2.6670 - accuracy: 0.3723 - val_loss: 2.4367 - val_accuracy: 0.3382 - lr: 0.0010
# Epoch 2/60
# c:\Users\ndhu2\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 306/306 [==============================] - ETA: 0s - loss: 2.0021 - accuracy: 0.4368
# Epoch 2: val_accuracy improved from 0.33817 to 0.42784, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1204s 4s/step - loss: 2.0021 - accuracy: 0.4368 - val_loss: 1.8731 - val_accuracy: 0.4278 - lr: 0.0010
# Epoch 3/60
# 306/306 [==============================] - ETA: 0s - loss: 1.6644 - accuracy: 0.4713
# Epoch 3: val_accuracy improved from 0.42784 to 0.44651, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1168s 4s/step - loss: 1.6644 - accuracy: 0.4713 - val_loss: 1.6610 - val_accuracy: 0.4465 - lr: 0.0010
# Epoch 4/60
# 306/306 [==============================] - ETA: 0s - loss: 1.5154 - accuracy: 0.5069
# Epoch 4: val_accuracy improved from 0.44651 to 0.46346, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1122s 4s/step - loss: 1.5154 - accuracy: 0.5069 - val_loss: 1.6312 - val_accuracy: 0.4635 - lr: 0.0010
# Epoch 5/60
# 306/306 [==============================] - ETA: 0s - loss: 1.4565 - accuracy: 0.5179
# Epoch 5: val_accuracy did not improve from 0.46346
# 306/306 [==============================] - 1121s 4s/step - loss: 1.4565 - accuracy: 0.5179 - val_loss: 1.7002 - val_accuracy: 0.4243 - lr: 0.0010
# Epoch 6/60
# 306/306 [==============================] - ETA: 0s - loss: 1.4151 - accuracy: 0.5305
# Epoch 6: val_accuracy improved from 0.46346 to 0.50981, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1151s 4s/step - loss: 1.4151 - accuracy: 0.5305 - val_loss: 1.4323 - val_accuracy: 0.5098 - lr: 0.0010
# Epoch 7/60
# 306/306 [==============================] - ETA: 0s - loss: 1.3938 - accuracy: 0.5354
# Epoch 7: val_accuracy did not improve from 0.50981
# 306/306 [==============================] - 1157s 4s/step - loss: 1.3938 - accuracy: 0.5354 - val_loss: 1.5194 - val_accuracy: 0.4694 - lr: 0.0010
# Epoch 8/60
# 306/306 [==============================] - ETA: 0s - loss: 1.3830 - accuracy: 0.5373
# Epoch 8: val_accuracy improved from 0.50981 to 0.52646, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1161s 4s/step - loss: 1.3830 - accuracy: 0.5373 - val_loss: 1.3895 - val_accuracy: 0.5265 - lr: 0.0010
# Epoch 9/60
# 306/306 [==============================] - ETA: 0s - loss: 1.3629 - accuracy: 0.5427
# Epoch 9: val_accuracy did not improve from 0.52646
# 306/306 [==============================] - 1139s 4s/step - loss: 1.3629 - accuracy: 0.5427 - val_loss: 1.4817 - val_accuracy: 0.5091 - lr: 0.0010
# Epoch 10/60
# 306/306 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.5461
# Epoch 10: val_accuracy did not improve from 0.52646
# 306/306 [==============================] - 1102s 4s/step - loss: 1.3473 - accuracy: 0.5461 - val_loss: 1.5013 - val_accuracy: 0.4743 - lr: 0.0010
# Epoch 11/60
# 306/306 [==============================] - ETA: 0s - loss: 1.2603 - accuracy: 0.5701
# Epoch 11: val_accuracy did not improve from 0.52646
# 306/306 [==============================] - 1095s 4s/step - loss: 1.2603 - accuracy: 0.5701 - val_loss: 1.3495 - val_accuracy: 0.5222 - lr: 5.0000e-04
# Epoch 12/60
# 306/306 [==============================] - ETA: 0s - loss: 1.2208 - accuracy: 0.5777
# Epoch 12: val_accuracy improved from 0.52646 to 0.55200, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1095s 4s/step - loss: 1.2208 - accuracy: 0.5777 - val_loss: 1.2870 - val_accuracy: 0.5520 - lr: 5.0000e-04
# Epoch 13/60
# 306/306 [==============================] - ETA: 0s - loss: 1.2026 - accuracy: 0.5775
# Epoch 13: val_accuracy did not improve from 0.55200
# 306/306 [==============================] - 1089s 4s/step - loss: 1.2026 - accuracy: 0.5775 - val_loss: 1.3133 - val_accuracy: 0.5292 - lr: 5.0000e-04
# Epoch 14/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1930 - accuracy: 0.5858
# Epoch 14: val_accuracy improved from 0.55200 to 0.55450, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1088s 4s/step - loss: 1.1930 - accuracy: 0.5858 - val_loss: 1.2484 - val_accuracy: 0.5545 - lr: 5.0000e-04
# Epoch 15/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1844 - accuracy: 0.5870
# Epoch 15: val_accuracy improved from 0.55450 to 0.55629, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1082s 4s/step - loss: 1.1844 - accuracy: 0.5870 - val_loss: 1.2490 - val_accuracy: 0.5563 - lr: 5.0000e-04
# Epoch 16/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1761 - accuracy: 0.5875
# Epoch 16: val_accuracy did not improve from 0.55629
# 306/306 [==============================] - 1067s 3s/step - loss: 1.1761 - accuracy: 0.5875 - val_loss: 1.2494 - val_accuracy: 0.5497 - lr: 5.0000e-04
# Epoch 17/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1716 - accuracy: 0.5895
# Epoch 17: val_accuracy improved from 0.55629 to 0.57025, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1038s 3s/step - loss: 1.1716 - accuracy: 0.5895 - val_loss: 1.2105 - val_accuracy: 0.5703 - lr: 5.0000e-04
# Epoch 18/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1655 - accuracy: 0.5919
# Epoch 18: val_accuracy improved from 0.57025 to 0.57437, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1044s 3s/step - loss: 1.1655 - accuracy: 0.5919 - val_loss: 1.2084 - val_accuracy: 0.5744 - lr: 5.0000e-04
# Epoch 19/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1596 - accuracy: 0.5911
# Epoch 19: val_accuracy did not improve from 0.57437
# 306/306 [==============================] - 1033s 3s/step - loss: 1.1596 - accuracy: 0.5911 - val_loss: 1.2672 - val_accuracy: 0.5486 - lr: 5.0000e-04
# Epoch 20/60
# 306/306 [==============================] - ETA: 0s - loss: 1.1568 - accuracy: 0.5967
# Epoch 20: val_accuracy did not improve from 0.57437
# 306/306 [==============================] - 1016s 3s/step - loss: 1.1568 - accuracy: 0.5967 - val_loss: 1.2999 - val_accuracy: 0.5304 - lr: 5.0000e-04
# Epoch 21/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0994 - accuracy: 0.6163
# Epoch 21: val_accuracy improved from 0.57437 to 0.60241, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1024s 3s/step - loss: 1.0994 - accuracy: 0.6163 - val_loss: 1.1281 - val_accuracy: 0.6024 - lr: 2.5000e-04
# Epoch 22/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0732 - accuracy: 0.6232
# Epoch 22: val_accuracy did not improve from 0.60241
# 306/306 [==============================] - 1012s 3s/step - loss: 1.0732 - accuracy: 0.6232 - val_loss: 1.1291 - val_accuracy: 0.5937 - lr: 2.5000e-04
# Epoch 23/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0630 - accuracy: 0.6271
# Epoch 23: val_accuracy did not improve from 0.60241
# 306/306 [==============================] - 1033s 3s/step - loss: 1.0630 - accuracy: 0.6271 - val_loss: 1.1359 - val_accuracy: 0.5893 - lr: 2.5000e-04
# Epoch 24/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0544 - accuracy: 0.6282
# Epoch 24: val_accuracy improved from 0.60241 to 0.60408, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1060s 3s/step - loss: 1.0544 - accuracy: 0.6282 - val_loss: 1.0978 - val_accuracy: 0.6041 - lr: 2.5000e-04
# Epoch 25/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0473 - accuracy: 0.6299
# Epoch 25: val_accuracy did not improve from 0.60408
# 306/306 [==============================] - 1072s 4s/step - loss: 1.0473 - accuracy: 0.6299 - val_loss: 1.1582 - val_accuracy: 0.5790 - lr: 2.5000e-04
# Epoch 26/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0365 - accuracy: 0.6325
# Epoch 26: val_accuracy did not improve from 0.60408
# 306/306 [==============================] - 1078s 4s/step - loss: 1.0365 - accuracy: 0.6325 - val_loss: 1.1412 - val_accuracy: 0.5841 - lr: 2.5000e-04
# Epoch 27/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0329 - accuracy: 0.6350
# Epoch 27: val_accuracy did not improve from 0.60408
# 306/306 [==============================] - 1083s 4s/step - loss: 1.0329 - accuracy: 0.6350 - val_loss: 1.1324 - val_accuracy: 0.6005 - lr: 2.5000e-04
# Epoch 28/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0305 - accuracy: 0.6357
# Epoch 28: val_accuracy did not improve from 0.60408
# 306/306 [==============================] - 1084s 4s/step - loss: 1.0305 - accuracy: 0.6357 - val_loss: 1.1063 - val_accuracy: 0.6027 - lr: 2.5000e-04
# Epoch 29/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0283 - accuracy: 0.6370
# Epoch 29: val_accuracy did not improve from 0.60408
# 306/306 [==============================] - 1092s 4s/step - loss: 1.0283 - accuracy: 0.6370 - val_loss: 1.1212 - val_accuracy: 0.5911 - lr: 2.5000e-04
# Epoch 30/60
# 306/306 [==============================] - ETA: 0s - loss: 1.0210 - accuracy: 0.6403
# Epoch 30: val_accuracy improved from 0.60408 to 0.60444, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1090s 4s/step - loss: 1.0210 - accuracy: 0.6403 - val_loss: 1.0986 - val_accuracy: 0.6044 - lr: 2.5000e-04
# Epoch 31/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9927 - accuracy: 0.6529
# Epoch 31: val_accuracy did not improve from 0.60444
# 306/306 [==============================] - 1099s 4s/step - loss: 0.9927 - accuracy: 0.6529 - val_loss: 1.1483 - val_accuracy: 0.5877 - lr: 1.2500e-04
# Epoch 32/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9691 - accuracy: 0.6593
# Epoch 32: val_accuracy improved from 0.60444 to 0.61673, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1100s 4s/step - loss: 0.9691 - accuracy: 0.6593 - val_loss: 1.0689 - val_accuracy: 0.6167 - lr: 1.2500e-04
# Epoch 33/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9631 - accuracy: 0.6611
# Epoch 33: val_accuracy did not improve from 0.61673
# 306/306 [==============================] - 1097s 4s/step - loss: 0.9631 - accuracy: 0.6611 - val_loss: 1.0719 - val_accuracy: 0.6162 - lr: 1.2500e-04
# Epoch 34/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9561 - accuracy: 0.6640
# Epoch 34: val_accuracy did not improve from 0.61673
# 306/306 [==============================] - 1106s 4s/step - loss: 0.9561 - accuracy: 0.6640 - val_loss: 1.0761 - val_accuracy: 0.6154 - lr: 1.2500e-04
# Epoch 35/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9443 - accuracy: 0.6716
# Epoch 35: val_accuracy did not improve from 0.61673
# 306/306 [==============================] - 1163s 4s/step - loss: 0.9443 - accuracy: 0.6716 - val_loss: 1.0628 - val_accuracy: 0.6143 - lr: 1.2500e-04
# Epoch 36/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9383 - accuracy: 0.6694
# Epoch 36: val_accuracy did not improve from 0.61673
# 306/306 [==============================] - 1252s 4s/step - loss: 0.9383 - accuracy: 0.6694 - val_loss: 1.0974 - val_accuracy: 0.6053 - lr: 1.2500e-04
# Epoch 37/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9329 - accuracy: 0.6735
# Epoch 37: val_accuracy improved from 0.61673 to 0.61739, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1087s 4s/step - loss: 0.9329 - accuracy: 0.6735 - val_loss: 1.0692 - val_accuracy: 0.6174 - lr: 1.2500e-04
# Epoch 38/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9321 - accuracy: 0.6744
# Epoch 38: val_accuracy improved from 0.61739 to 0.61900, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1119s 4s/step - loss: 0.9321 - accuracy: 0.6744 - val_loss: 1.0690 - val_accuracy: 0.6190 - lr: 1.2500e-04
# Epoch 39/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9262 - accuracy: 0.6761
# Epoch 39: val_accuracy improved from 0.61900 to 0.62132, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1414s 5s/step - loss: 0.9262 - accuracy: 0.6761 - val_loss: 1.0731 - val_accuracy: 0.6213 - lr: 1.2500e-04
# Epoch 40/60
# 306/306 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.6793
# Epoch 40: val_accuracy improved from 0.62132 to 0.62222, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1638s 5s/step - loss: 0.9217 - accuracy: 0.6793 - val_loss: 1.0529 - val_accuracy: 0.6222 - lr: 1.2500e-04
# Epoch 41/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8980 - accuracy: 0.6866
# Epoch 41: val_accuracy improved from 0.62222 to 0.62801, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 1102s 4s/step - loss: 0.8980 - accuracy: 0.6866 - val_loss: 1.0356 - val_accuracy: 0.6280 - lr: 6.2500e-05
# Epoch 42/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8884 - accuracy: 0.6901
# Epoch 42: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 1130s 4s/step - loss: 0.8884 - accuracy: 0.6901 - val_loss: 1.0525 - val_accuracy: 0.6183 - lr: 6.2500e-05
# Epoch 43/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8780 - accuracy: 0.6966
# Epoch 43: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 1087s 4s/step - loss: 0.8780 - accuracy: 0.6966 - val_loss: 1.0436 - val_accuracy: 0.6238 - lr: 6.2500e-05
# Epoch 44/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8726 - accuracy: 0.6964
# Epoch 44: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 990s 3s/step - loss: 0.8726 - accuracy: 0.6964 - val_loss: 1.0433 - val_accuracy: 0.6268 - lr: 6.2500e-05
# Epoch 45/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8686 - accuracy: 0.6983
# Epoch 45: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 985s 3s/step - loss: 0.8686 - accuracy: 0.6983 - val_loss: 1.0566 - val_accuracy: 0.6239 - lr: 6.2500e-05
# Epoch 46/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8594 - accuracy: 0.7040
# Epoch 46: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 988s 3s/step - loss: 0.8594 - accuracy: 0.7040 - val_loss: 1.0485 - val_accuracy: 0.6256 - lr: 6.2500e-05
# Epoch 47/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8577 - accuracy: 0.7039
# Epoch 47: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 985s 3s/step - loss: 0.8577 - accuracy: 0.7039 - val_loss: 1.0624 - val_accuracy: 0.6195 - lr: 6.2500e-05
# Epoch 48/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8491 - accuracy: 0.7077
# Epoch 48: val_accuracy did not improve from 0.62801
# 306/306 [==============================] - 985s 3s/step - loss: 0.8491 - accuracy: 0.7077 - val_loss: 1.0464 - val_accuracy: 0.6279 - lr: 6.2500e-05
# Epoch 49/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8462 - accuracy: 0.7097
# Epoch 49: val_accuracy improved from 0.62801 to 0.62932, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 990s 3s/step - loss: 0.8462 - accuracy: 0.7097 - val_loss: 1.0449 - val_accuracy: 0.6293 - lr: 6.2500e-05
# Epoch 50/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8466 - accuracy: 0.7094
# Epoch 50: val_accuracy improved from 0.62932 to 0.63505, saving model to D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs\age_model_checkpoint.h5
# 306/306 [==============================] - 994s 3s/step - loss: 0.8466 - accuracy: 0.7094 - val_loss: 1.0425 - val_accuracy: 0.6350 - lr: 6.2500e-05
# Epoch 51/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8329 - accuracy: 0.7145
# Epoch 51: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 991s 3s/step - loss: 0.8329 - accuracy: 0.7145 - val_loss: 1.0515 - val_accuracy: 0.6315 - lr: 3.1250e-05
# Epoch 52/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8265 - accuracy: 0.7178
# Epoch 52: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 998s 3s/step - loss: 0.8265 - accuracy: 0.7178 - val_loss: 1.0456 - val_accuracy: 0.6336 - lr: 3.1250e-05
# Epoch 53/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8207 - accuracy: 0.7211
# Epoch 53: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 994s 3s/step - loss: 0.8207 - accuracy: 0.7211 - val_loss: 1.0875 - val_accuracy: 0.6245 - lr: 3.1250e-05
# Epoch 54/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8110 - accuracy: 0.7264
# Epoch 54: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 988s 3s/step - loss: 0.8110 - accuracy: 0.7264 - val_loss: 1.0650 - val_accuracy: 0.6292 - lr: 3.1250e-05
# Epoch 55/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.7253
# Epoch 55: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 993s 3s/step - loss: 0.8068 - accuracy: 0.7253 - val_loss: 1.0572 - val_accuracy: 0.6315 - lr: 3.1250e-05
# Epoch 56/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8054 - accuracy: 0.7265
# Epoch 56: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 992s 3s/step - loss: 0.8054 - accuracy: 0.7265 - val_loss: 1.0651 - val_accuracy: 0.6312 - lr: 3.1250e-05
# Epoch 57/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8031 - accuracy: 0.7270
# Epoch 57: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 985s 3s/step - loss: 0.8031 - accuracy: 0.7270 - val_loss: 1.0539 - val_accuracy: 0.6304 - lr: 3.1250e-05
# Epoch 58/60
# 306/306 [==============================] - ETA: 0s - loss: 0.8005 - accuracy: 0.7323
# Epoch 58: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 989s 3s/step - loss: 0.8005 - accuracy: 0.7323 - val_loss: 1.0723 - val_accuracy: 0.6310 - lr: 3.1250e-05
# Epoch 59/60
# 306/306 [==============================] - ETA: 0s - loss: 0.7945 - accuracy: 0.7316
# Epoch 59: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 989s 3s/step - loss: 0.7945 - accuracy: 0.7316 - val_loss: 1.0516 - val_accuracy: 0.6282 - lr: 3.1250e-05
# Epoch 60/60
# 306/306 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.7321
# Epoch 60: val_accuracy did not improve from 0.63505
# 306/306 [==============================] - 993s 3s/step - loss: 0.7901 - accuracy: 0.7321 - val_loss: 1.0741 - val_accuracy: 0.6279 - lr: 3.1250e-05

# %%
# Checking the train and test loss and accuracy values from the neural network above.
train_loss = final_cnn_history.history['loss']
test_loss = final_cnn_history.history['val_loss']
train_accuracy = final_cnn_history.history['accuracy']
test_accuracy = final_cnn_history.history['val_accuracy']



# Plotting a line chart to visualize the loss and accuracy values by epochs.
fig, ax = plt.subplots(ncols=2, figsize=(15,7))
ax = ax.ravel()
ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)
ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)
ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)
ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)
ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)
ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)
ax[1].set_ylim(0, 1)


fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)


# Exporting plot image in PNG format.
plt.savefig('D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs/final_cnn_loss_accuracy.png', bbox_inches='tight')

# %%
# Evaluating the model on test dataset.
final_cnn_score = final_cnn.evaluate(test_dataset, verbose=1)
# Printing the relevant score summary.
final_cnn_labels = final_cnn.metrics_names
print(f'CNN model {final_cnn_labels[0]} \t\t= {round(final_cnn_score[0], 3)}')
print(f'CNN model {final_cnn_labels[1]} \t= {round(final_cnn_score[1], 3)}')

# Saving the model as a keras file for possible use later.
final_cnn.save(f"D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/age_model_acc_{round(final_cnn_score[1], 3)}.h5", save_format='h5')

# Generating predictions from the model above.
final_cnn_pred = final_cnn.predict(test_dataset)
final_cnn_pred = final_cnn_pred.argmax(axis=-1)
# Generating a confusion matrix based on above predictions.
test_labels_list = list(val['target'].astype('int64'))
conf_mat = confusion_matrix(test_labels_list, final_cnn_pred)

# Defining a function to plot the confusion matrix in a grid for easier visualization.
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', export_as='confusion_matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    # print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=16)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True labels', fontsize=14)
    plt.xlabel('Predicted labels', fontsize=14)
    # Exporting plot image in PNG format.
    plt.savefig(f'D:/Users/ndhu2/Classes/Introduction to AI/Project/Models/FM2/cnn_logs/{export_as}.png', bbox_inches='tight');

# Plotting the confusion matrix using the function defined above.
cm_plot_labels = ['1-12', '13-18', '19-30', '31-42', '43-...']

plt.figure(figsize=(16,8))
plot_confusion_matrix(conf_mat, cm_plot_labels, normalize=True,
                      title="Confusion Matrix based on predictions from CNN model",
                      export_as="final_cnn_conf_mat_norm"
                     )
plt.show()
# Out:
# 131/131 [==============================] - 160s 1s/step - loss: 1.0105 - accuracy: 0.5871
# CNN model loss 		= 1.011
# CNN model accuracy 	= 0.587
# 131/131 [==============================] - 100s 757ms/step
# Normalized confusion matrix
